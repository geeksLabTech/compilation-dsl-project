# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_list>},
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 4 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 5 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 6 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 7 	 <stat> -> <if-stat>.,
#
# 8 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 9 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 10 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
#
# 11 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 12 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 13 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 14 	 <else-stat> -> else.{<stat_list>},
#
# 15 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 16 	 <while-stat> -> while.(<expr>){<stat_list>},
#
# 17 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <while-stat> -> while(.<expr>){<stat_list>},
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 18 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <while-stat> -> while(<expr>.){<stat_list>},
#
# 19 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 20 	 <factor> -> <func-call>.,
#
# 21 	 <atom> -> false.,
#
# 22 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> (.<expr>),
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 23 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.<=<term>,
#
# 24 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
# 	 <expr> -> <expr>==.<term>,
#
# 25 	 <factor> -> <atom>.,
#
# 26 	 <term> -> <factor>.,
#
# 27 	 <atom> -> ".string_text",
#
# 28 	 <atom> -> "string_text.",
#
# 29 	 <atom> -> "string_text".,
#
# 30 	 <atom> -> num.,
#
# 31 	 <atom> -> true.,
#
# 32 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 33 	 <arg-list> -> .id,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <func-call> -> id(.<arg-list>),
#
# 34 	 <arg-list> -> id.,
# 	 <arg-list> -> id.,<arg-list>,
#
# 35 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> .id,<arg-list>,
#
# 36 	 <arg-list> -> id,<arg-list>.,
#
# 37 	 <func-call> -> id(<arg-list>.),
#
# 38 	 <func-call> -> id(<arg-list>).,
#
# 39 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 40 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> <term>*.<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 41 	 <term> -> <term>*<factor>.,
#
# 42 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> <term>/.<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 43 	 <term> -> <term>/<factor>.,
#
# 44 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <expr> -> <expr>>=.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 45 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 46 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 47 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr><<term>.,
#
# 48 	 <expr> -> <expr>!=.<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 49 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>!=<term>.,
#
# 50 	 <factor> -> (<expr>).,
#
# 51 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 52 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr><=<term>.,
#
# 53 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr>+.<term>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 54 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 55 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <expr> -> <expr>>.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
#
# 56 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>.*<factor>,
#
# 57 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <term>.,
#
# 58 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>-<term>.,
#
# 59 	 <while-stat> -> while(<expr>).{<stat_list>},
#
# 60 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <while-stat> -> while(<expr>){.<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 61 	 <stat> -> <let-var>>.,
#
# 62 	 <stat> -> <def-entry>.,
#
# 63 	 <stat> -> <var-call>.,
#
# 64 	 <let-var>> -> let.id:type=<expr>;,
#
# 65 	 <let-var>> -> letid.:type=<expr>;,
#
# 66 	 <let-var>> -> letid:.type=<expr>;,
#
# 67 	 <let-var>> -> letid:type.=<expr>;,
#
# 68 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 69 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.<=<term>,
#
# 70 	 <let-var>> -> letid:type=<expr>;.,
#
# 71 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 72 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 73 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.<=<term>,
#
# 74 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 75 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 76 	 <stat> -> <def-func>.,
#
# 77 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 78 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.<=<term>,
#
# 79 	 <return-stat> -> return<expr>;.,
#
# 80 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 81 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 82 	 <stat> -> <else-stat>.,
#
# 83 	 <stat> -> <return-stat>.,
#
# 84 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 85 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 86 	 <param-list> -> .<param>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
#
# 87 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 88 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 89 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 90 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 91 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 92 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 93 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 94 	 <var-call> -> id.=<expr>;,
#
# 95 	 <expr> -> .<expr>==<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <var-call> -> id=.<expr>;,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>+<term>,
#
# 96 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.<=<term>,
#
# 97 	 <var-call> -> id=<expr>;.,
#
# 98 	 <stat> -> <while-stat>.,
#
# 99 	 <stat_list> -> <stat_list><stat>.,
#
# 100 	 <stat_list> -> <stat>.,
#
# 101 	 <param> -> id.:type,
#
# 102 	 <param> -> id:.type,
#
# 103 	 <param> -> id:type.,
#
# 104 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 105 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
#
# 106 	 <param-list> -> <param>,<param-list>.,
#
# 107 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <while-stat> -> while(<expr>){<stat_list>.},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 108 	 <while-stat> -> while(<expr>){<stat_list>}.,
#
# 109 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 110 	 <else-stat> -> else{<stat_list>}.,
#
# 111 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 112 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 113 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
#
# 114 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 115 	 S' -> <program>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat> -> <def-entry>,
#  <stat_list> -> <stat_list> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <expr> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat> -> <def-func>,
#  <stat_list> -> <stat_list> <stat>,
#  <program> -> contract id ( <param-list> ) { <stat_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 4
#       2 ast = build_slr_ast(productions, operations, tokens)
#       3 format = FormatVisitor()
# ----> 4 print(format.visit(ast))
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:26, in FormatVisitor.visit(self, node, tabs)
#      22 ans = '\t' * tabs + \
#      23     f'\\__ProgramNode: contract node.idx({sparams}) [<stat>; ... <stat>;]'
#      24 params = '\n'.join(self.visit(param, tabs + 1)
#      25                    for param in node.params)
# ---> 26 statements = '\n'.join(self.visit(child, tabs + 2)
#      27                        for child in node.statements)
#      28 return f'{ans}\n{params}\n{statements}'
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:26, in <genexpr>(.0)
#      22 ans = '\t' * tabs + \
#      23     f'\\__ProgramNode: contract node.idx({sparams}) [<stat>; ... <stat>;]'
#      24 params = '\n'.join(self.visit(param, tabs + 1)
#      25                    for param in node.params)
# ---> 26 statements = '\n'.join(self.visit(child, tabs + 2)
#      27                        for child in node.statements)
#      28 return f'{ans}\n{params}\n{statements}'
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:88, in FormatVisitor.visit(self, node, tabs)
#      83 ans = '\t' * tabs + \
#      84     f'\\__EntryDeclarationNode: Entry {node.id}({sparams})'
#      85 params = '\n'.join(self.visit(param, tabs + 1)
#      86                    for param in node.params)
# ---> 88 body = '\n'.join(self.visit(child, tabs + 2) for child in node.body)
#      91 return f'{ans}\n{params}\n{body}'
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:88, in <genexpr>(.0)
#      83 ans = '\t' * tabs + \
#      84     f'\\__EntryDeclarationNode: Entry {node.id}({sparams})'
#      85 params = '\n'.join(self.visit(param, tabs + 1)
#      86                    for param in node.params)
# ---> 88 body = '\n'.join(self.visit(child, tabs + 2) for child in node.body)
#      91 return f'{ans}\n{params}\n{body}'
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:40, in FormatVisitor.visit(self, node, tabs)
#      36 @visitor.when(VarDeclarationNode)
#      37 def visit(self, node, tabs=0):
#      38     ans = '\t' * tabs + \
#      39         f'\\__VarDeclarationNode: let {node.id} = <expr> : {node.type}'
# ---> 40     expr = self.visit(node.expr, tabs + 1)
#      41     return f'{ans}\n{expr}'
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:115, in FormatVisitor.visit(self, node, tabs)
#     112 @visitor.when(CallNode)
#     113 def visit(self, node, tabs=0):
#     114     ans = '\t' * tabs + f'\\__CallNode: {node.id}(<expr>, ..., <expr>)'
# --> 115     args = '\n'.join(self.visit(arg, tabs + 1) for arg in node.args)
#     116     return f'{ans}\n{args}'
#
# TypeError: sequence item 0: expected str instance, list found
