# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# self,  <program>
# other (contract id ( <param-list> ) { <stat_list> }, <function <lambda> at 0x1073d4180>, None, None, None, None, None, None, None, None)
# self,  <stat_list>
# other ('<stat>', <function <lambda> at 0x1073d79c0>, None)
# self,  <stat_list>
# other (<stat> <stat_list>, <function <lambda> at 0x1073d7a60>, None, None)
# self,  <stat>
# other ('<def-func>', <function <lambda> at 0x1073d7b00>, None)
# self,  <stat>
# other ('<def-entry>', <function <lambda> at 0x1073d7ba0>, None)
# self,  <stat>
# other ('<if-stat>', <function <lambda> at 0x1073d7c40>, None)
# self,  <stat>
# other ('<else-stat>', <function <lambda> at 0x1073d7ce0>, None)
# self,  <stat>
# other ('<return-stat>', <function <lambda> at 0x1073d7e20>, None)
# self,  <stat>
# other ('<var-call>', <function <lambda> at 0x1073d7f60>, None)
# self,  <stat>
# other ('<let-var>>', <function <lambda> at 0x107c24040>, None)
# self,  <if-stat>
# other (if ( <expr> ) { <stat_list> }, <function <lambda> at 0x107c240e0>, None, None, None, None, None, None, None)
# self,  <else-stat>
# other (else { <stat_list> }, <function <lambda> at 0x107c24180>, None, None, None, None)
# self,  <return-stat>
# other (return <expr> ;, <function <lambda> at 0x107c24220>, None, None, None)
# self,  <def-func>
# other (func id ( <param-list> ) : type { <stat_list> }, <function <lambda> at 0x107c24360>, None, None, None, None, None, None, None, None, None, None)
# self,  <def-entry>
# other (entry id ( <param-list> ) { <stat_list> }, <function <lambda> at 0x107c244a0>, None, None, None, None, None, None, None, None)
# self,  <param-list>
# other ('<param>', <function <lambda> at 0x107c24540>, None)
# self,  <param-list>
# other (<param> , <param-list>, <function <lambda> at 0x107c245e0>, None, None, None)
# self,  <param>
# other (id : type, <function <lambda> at 0x107c24720>, None, None, None)
# self,  <expr-list>
# other ('<expr>', <function <lambda> at 0x107c247c0>, None)
# self,  <expr-list>
# other (<expr> , <expr-list>, <function <lambda> at 0x107c24860>, None, None, None)
# self,  <expr>
# other (<expr> + <term>, <function <lambda> at 0x107c24900>, None, None, None)
# self,  <expr>
# other (<expr> - <term>, <function <lambda> at 0x107c249a0>, None, None, None)
# self,  <expr>
# other (<expr> == <term>, <function <lambda> at 0x107c24a40>, None, None, None)
# self,  <expr>
# other (<expr> <= <term>, <function <lambda> at 0x107c24ae0>, None, None, None)
# self,  <expr>
# other (<expr> >= <term>, <function <lambda> at 0x107c24b80>, None, None, None)
# self,  <expr>
# other (<expr> != <term>, <function <lambda> at 0x107c24c20>, None, None, None)
# self,  <expr>
# other (<expr> < <term>, <function <lambda> at 0x107c24cc0>, None, None, None)
# self,  <expr>
# other (<expr> > <term>, <function <lambda> at 0x107c24d60>, None, None, None)
# self,  <expr>
# other ('<term>', <function <lambda> at 0x107c24e00>, None)
# self,  <term>
# other (<term> * <factor>, <function <lambda> at 0x107c24ea0>, None, None, None)
# self,  <term>
# other (<term> / <factor>, <function <lambda> at 0x107c24f40>, None, None, None)
# self,  <term>
# other ('<factor>', <function <lambda> at 0x107c24fe0>, None)
# self,  <factor>
# other ('<atom>', <function <lambda> at 0x107c25080>, None)
# self,  <factor>
# other ('<func-call>', <function <lambda> at 0x107c25120>, None)
# self,  <factor>
# other (( <expr> ), <function <lambda> at 0x107c251c0>, None, None, None)
# self,  <atom>
# other ('num', <function <lambda> at 0x107c25260>, None)
# self,  <atom>
# other ('id', <function <lambda> at 0x107c25300>, None)
# self,  <atom>
# other ('true', <function <lambda> at 0x107c253a0>, None)
# self,  <atom>
# other ('false', <function <lambda> at 0x107c25440>, None)
# self,  <func-call>
# other (id ( <arg-list> ), <function <lambda> at 0x107c254e0>, None, None, None, None)
# self,  <var-call>
# other (id = <expr> ;, <function <lambda> at 0x107c25580>, None, None, None, None)
# self,  <let-var>>
# other (let id : type = <expr> ;, <function <lambda> at 0x107c25620>, None, None, None, None, None, None, None)
# self,  <arg-list>
# other ('id', <function <lambda> at 0x107c256c0>, None)
# self,  <arg-list>
# other (id , <arg-list>, <function <lambda> at 0x107c25760>, None, None, None)
# self,  Exp
# other (Term Term_2, <function <lambda> at 0x1077b7ce0>, None, <function <lambda> at 0x1077b7d80>)
# self,  Term
# other (Factor Factor_2, <function <lambda> at 0x1077b7e20>, None, <function <lambda> at 0x1077c1a80>)
# self,  Term_2
# other (| Exp, <function <lambda> at 0x1077c1b20>, None, None)
# self,  Term_2
# other (epsilon, <function <lambda> at 0x1077c1bc0>)
# self,  Factor
# other (Atom Atom_2, <function <lambda> at 0x1077c1c60>, None, <function <lambda> at 0x1077c1d00>)
# self,  Factor_2
# other ('Term', <function <lambda> at 0x1077c1da0>, None)
# self,  Factor_2
# other (epsilon, <function <lambda> at 0x1077c1e40>)
# self,  Atom
# other ('Char', <function <lambda> at 0x1077c1ee0>, None)
# self,  Atom
# other (( Exp ), <function <lambda> at 0x1077c1f80>, None, None, None)
# self,  Atom
# other ([ CharClass ], <function <lambda> at 0x1077c2020>, None, None, None)
# self,  Atom_2
# other ('MetaChar', <function <lambda> at 0x1077c20c0>, <function <lambda> at 0x1077c2160>)
# self,  Atom_2
# other (epsilon, <function <lambda> at 0x1077c22a0>)
# self,  CharClass
# other (CharClassItem CharClassItem_2, <function <lambda> at 0x1077c2340>, None, <function <lambda> at 0x1077c23e0>)
# self,  CharClassItem
# other (Char Char_2, <function <lambda> at 0x1077c2480>, None, <function <lambda> at 0x1077c2520>)
# self,  CharClassItem_2
# other ('CharClass', <function <lambda> at 0x1077c25c0>, None)
# self,  CharClassItem_2
# other (epsilon, <function <lambda> at 0x1077c2660>)
# self,  Char
# other ('AnyChar', <function <lambda> at 0x1077c2700>, None)
# self,  Char
# other (\ AnyChar, <function <lambda> at 0x1077c27a0>, None, None)
# self,  Char_2
# other (- Char, <function <lambda> at 0x1077c2840>, None, None)
# self,  Char_2
# other (epsilon, <function <lambda> at 0x1077c28e0>)
# self,  CharCount
# other (Integer Integer_2, <function <lambda> at 0x1077c2980>, None, None)
# self,  Integer
# other (Digit Digit_2, <function <lambda> at 0x1077c2a20>, None, None)
# self,  Integer_2
# other (, Integer_3, <function <lambda> at 0x1077c2ac0>, None, None)
# self,  Integer_2
# other (epsilon, <function <lambda> at 0x1077c2b60>)
# self,  Integer_3
# other ('Integer', <function <lambda> at 0x1077c2c00>, None)
# self,  Integer_3
# other (epsilon, <function <lambda> at 0x1077c2ca0>)
# self,  Digit
# other ('0', <function <lambda> at 0x1077c2d40>, None)
# self,  Digit
# other ('1', <function <lambda> at 0x1077c2de0>, None)
# self,  Digit
# other ('2', <function <lambda> at 0x1077c2e80>, None)
# self,  Digit
# other ('3', <function <lambda> at 0x1077c2f20>, None)
# self,  Digit
# other ('4', <function <lambda> at 0x1077c2fc0>, None)
# self,  Digit
# other ('5', <function <lambda> at 0x1077c3060>, None)
# self,  Digit
# other ('6', <function <lambda> at 0x1077c3100>, None)
# self,  Digit
# other ('7', <function <lambda> at 0x1077c31a0>, None)
# self,  Digit
# other ('8', <function <lambda> at 0x1077c3240>, None)
# self,  Digit
# other ('9', <function <lambda> at 0x1077c32e0>, None)
# self,  Digit_2
# other ('Integer', <function <lambda> at 0x1077c3380>, None)
# self,  Digit_2
# other (epsilon, <function <lambda> at 0x1077c3420>)
# self,  AnyChar
# other ('Digit', <function <lambda> at 0x1077c34c0>, None)
# self,  AnyChar
# other ('any_char', <function <lambda> at 0x1077c3560>, None)
# self,  MetaChar
# other ('?', <function <lambda> at 0x1077c3600>, None)
# self,  MetaChar
# other ('*', <function <lambda> at 0x1077c36a0>, None)
# self,  MetaChar
# other ('+', <function <lambda> at 0x1077c3740>, None)
# self,  S'
# other (<program>, <function Grammar.AugmentedGrammar.<locals>.<lambda> at 0x1073c2ca0>)
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_list>},
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 4 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 5 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> <param>,.<param-list>,
#
# 6 	 <param-list> -> <param>,<param-list>.,
#
# 7 	 <param> -> id.:type,
#
# 8 	 <param> -> id:.type,
#
# 9 	 <param> -> id:type.,
#
# 10 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 11 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 12 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-entry>,
#
# 13 	 <stat_list> -> <stat>.,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> <stat>.<stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-entry>,
#
# 14 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 15 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><=<term>,
#
# 16 	 <atom> -> num.,
#
# 17 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 18 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <term> -> <term>*.<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
#
# 19 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 20 	 <arg-list> -> .id,<arg-list>,
# 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,
#
# 21 	 <func-call> -> id(<arg-list>.),
#
# 22 	 <func-call> -> id(<arg-list>).,
#
# 23 	 <arg-list> -> id.,
# 	 <arg-list> -> id.,<arg-list>,
#
# 24 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 25 	 <arg-list> -> id,<arg-list>.,
#
# 26 	 <atom> -> false.,
#
# 27 	 <factor> -> <func-call>.,
#
# 28 	 <term> -> <term>*<factor>.,
#
# 29 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr><<term>,
# 	 <factor> -> (.<expr>),
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><=<term>,
#
# 30 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 31 	 <term> -> .<factor>,
# 	 <expr> -> <expr>==.<term>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 32 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>==<term>.,
#
# 33 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <term> -> <term>/.<factor>,
# 	 <factor> -> .(<expr>),
#
# 34 	 <term> -> <term>/<factor>.,
#
# 35 	 <factor> -> <atom>.,
#
# 36 	 <atom> -> true.,
#
# 37 	 <term> -> <factor>.,
#
# 38 	 <factor> -> (<expr>).,
#
# 39 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> <expr>!=.<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 40 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>!=<term>.,
#
# 41 	 <term> -> .<factor>,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 42 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 43 	 <expr> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 44 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr><<term>.,
#
# 45 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <expr> -> <expr>>.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 46 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>><term>.,
#
# 47 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr>>=.<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 48 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 49 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> <expr>-.<term>,
#
# 50 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>-<term>.,
#
# 51 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <expr> -> <expr>+.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 52 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>+<term>.,
#
# 53 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 54 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 55 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-entry>,
#
# 56 	 <if-stat> -> if(<expr>){<stat_list>.},
#
# 57 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 58 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr><<term>,
# 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><=<term>,
#
# 59 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 60 	 <return-stat> -> return<expr>;.,
#
# 61 	 <stat> -> <var-call>.,
#
# 62 	 <stat> -> <else-stat>.,
#
# 63 	 <let-var>> -> let.id:type=<expr>;,
#
# 64 	 <let-var>> -> letid.:type=<expr>;,
#
# 65 	 <let-var>> -> letid:.type=<expr>;,
#
# 66 	 <let-var>> -> letid:type.=<expr>;,
#
# 67 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr><<term>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><=<term>,
#
# 68 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 69 	 <let-var>> -> letid:type=<expr>;.,
#
# 70 	 <var-call> -> id.=<expr>;,
#
# 71 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<term>*<factor>,
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><=<term>,
#
# 72 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 73 	 <var-call> -> id=<expr>;.,
#
# 74 	 <stat> -> <def-func>.,
#
# 75 	 <stat> -> <return-stat>.,
#
# 76 	 <else-stat> -> else.{<stat_list>},
#
# 77 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<def-entry>,
#
# 78 	 <else-stat> -> else{<stat_list>.},
#
# 79 	 <else-stat> -> else{<stat_list>}.,
#
# 80 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 81 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 82 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
#
# 83 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 84 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 85 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 86 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 87 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-entry>,
#
# 88 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
#
# 89 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 90 	 <stat> -> <def-entry>.,
#
# 91 	 <stat> -> <if-stat>.,
#
# 92 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 93 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 94 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param> -> .id:type,
#
# 95 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 96 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 97 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<def-func>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-entry>,
#
# 98 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
#
# 99 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 100 	 <stat> -> <let-var>>.,
#
# 101 	 <stat_list> -> <stat><stat_list>.,
#
# 102 	 <program> -> contractid(<param-list>){<stat_list>.},
#
# 103 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 104 	 S' -> <program>.,
#
# [0] <---||---> ['contract', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 7] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 7, ':', 8] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 7, ':', 8, 'type', 9] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param>', 4] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12] <---||---> ['let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63] <---||---> ['id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64] <---||---> [':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65] <---||---> ['type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66] <---||---> ['=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67] <---||---> ['num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, 'num', 16] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<atom>', 35] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<factor>', 37] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<term>', 17] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, ';', 69] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<let-var>>', 100] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, 'id', 7] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, 'id', 7, ':', 8] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, 'id', 7, ':', 8, 'type', 9] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param>', 4] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97] <---||---> ['let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63] <---||---> ['id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64] <---||---> [':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64, ':', 65] <---||---> ['type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64, ':', 65, 'type', 66] <---||---> ['=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67] <---||---> ['id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, 'id', 19] <---||---> ['(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, 'entry', 92, 'id', 93, '(', 94, '<param-list>', 95, ')', 96, '{', 97, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, 'id', 19, '(', 20] <---||---> ['id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# ...
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<term>', 17] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, '-', 49] <---||---> ['num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, '-', 49, 'num', 16] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, '-', 49, '<atom>', 35] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, '-', 49, '<factor>', 37] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, '-', 49, '<term>', 50] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, 'let', 63, 'id', 64, ':', 65, 'type', 66, '=', 67, '<expr>', 68, ';', 69] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<let-var>>', 100] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58] <---||---> ['id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, 'id', 19] <---||---> ['(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, 'id', 19, '(', 20] <---||---> ['id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, 'id', 19, '(', 20, 'id', 23] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, 'id', 19, '(', 20, '<arg-list>', 21] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, 'id', 19, '(', 20, '<arg-list>', 21, ')', 22] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<func-call>', 27] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<factor>', 37] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<term>', 17] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51] <---||---> ['id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, 'id', 19] <---||---> ['(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, 'id', 19, '(', 20] <---||---> ['id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, 'id', 19, '(', 20, 'id', 23] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, 'id', 19, '(', 20, '<arg-list>', 21] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, 'id', 19, '(', 20, '<arg-list>', 21, ')', 22] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, '<func-call>', 27] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, '<factor>', 37] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, '+', 51, '<term>', 52] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, 'return', 58, '<expr>', 59, ';', 60] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, '<return-stat>', 75] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, '<stat>', 13] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat>', 13, '<stat_list>', 101] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat>', 13, '<stat_list>', 101] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat_list>', 78] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, 'else', 76, '{', 77, '<stat_list>', 78, '}', 79] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, '<else-stat>', 62] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, '<stat>', 13] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat>', 13, '<stat_list>', 101] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat_list>', 88] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, 'func', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, ':', 85, 'type', 86, '{', 87, '<stat_list>', 88, '}', 89] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, '<def-func>', 74] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, '<stat>', 13] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat>', 13, '<stat_list>', 101] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 13, '<stat_list>', 101] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat_list>', 102] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat_list>', 102, '}', 103] <---||---> ['$']
# [0, '<program>', 104] <---||---> ['$']

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat>,
#  <stat_list> -> <stat> <stat_list>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat> -> <def-entry>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <expr> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <stat_list> -> <stat> <stat_list>,
#  <stat_list> -> <stat> <stat_list>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat>,
#  <stat_list> -> <stat> <stat_list>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat> -> <def-func>,
#  <stat_list> -> <stat>,
#  <stat_list> -> <stat> <stat_list>,
#  <stat_list> -> <stat> <stat_list>,
#  <program> -> contract id ( <param-list> ) { <stat_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']
