# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_list>},
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 4 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 5 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 6 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 7 	 <stat> -> <return-stat>.,
#
# 8 	 <else-stat> -> else.{<stat_list>},
#
# 9 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 10 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 11 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 12 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
#
# 13 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 14 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 15 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 16 	 <stat> -> <while-stat>.,
#
# 17 	 <stat> -> <let-var>>.,
#
# 18 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 19 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 20 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param> -> .id:type,
#
# 21 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 22 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 23 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 24 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 25 	 <stat> -> .<else-stat>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 26 	 <stat_list> -> <stat>.,
#
# 27 	 <stat> -> <else-stat>.,
#
# 28 	 <while-stat> -> while.(<expr>){<stat_list>},
#
# 29 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <while-stat> -> while(.<expr>){<stat_list>},
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
#
# 30 	 <factor> -> <func-call>.,
#
# 31 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <while-stat> -> while(<expr>.){<stat_list>},
#
# 32 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <expr> -> <expr>!=.<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 33 	 <atom> -> num.,
#
# 34 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>!=<term>.,
#
# 35 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> <term>*.<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 36 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <factor> -> (.<expr>),
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
#
# 37 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <factor> -> (<expr>.),
#
# 38 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>>.<term>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 39 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 40 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 41 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 42 	 <arg-list> -> .id,<arg-list>,
# 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,
#
# 43 	 <func-call> -> id(<arg-list>.),
#
# 44 	 <func-call> -> id(<arg-list>).,
#
# 45 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 46 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> id,.<arg-list>,
#
# 47 	 <arg-list> -> id,<arg-list>.,
#
# 48 	 <factor> -> <atom>.,
#
# 49 	 <atom> -> ".string_text",
#
# 50 	 <atom> -> "string_text.",
#
# 51 	 <atom> -> "string_text".,
#
# 52 	 <atom> -> false.,
#
# 53 	 <term> -> <term>/<factor>.,
#
# 54 	 <atom> -> true.,
#
# 55 	 <term> -> <factor>.,
#
# 56 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> <expr>>=.<term>,
# 	 <func-call> -> .id(<arg-list>),
#
# 57 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>>=<term>.,
#
# 58 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 59 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 60 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 61 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>./<factor>,
#
# 62 	 <factor> -> (<expr>).,
#
# 63 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <expr> -> <expr>==.<term>,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 64 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>==<term>.,
#
# 65 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr><.<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 66 	 <expr> -> <expr><<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 67 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
#
# 68 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
#
# 69 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 70 	 <term> -> <term>*<factor>.,
#
# 71 	 <while-stat> -> while(<expr>).{<stat_list>},
#
# 72 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> while(<expr>){.<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 73 	 <let-var>> -> let.id:type=<expr>;,
#
# 74 	 <let-var>> -> letid.:type=<expr>;,
#
# 75 	 <let-var>> -> letid:.type=<expr>;,
#
# 76 	 <let-var>> -> letid:type.=<expr>;,
#
# 77 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
#
# 78 	 <expr> -> <expr>.==<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
#
# 79 	 <let-var>> -> letid:type=<expr>;.,
#
# 80 	 <stat> -> <def-entry>.,
#
# 81 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <return-stat> -> return.<expr>;,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
#
# 82 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
#
# 83 	 <return-stat> -> return<expr>;.,
#
# 84 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 85 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
#
# 86 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
#
# 87 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 88 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 89 	 <stat> -> <var-call>.,
#
# 90 	 <var-call> -> id.=<expr>;,
#
# 91 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>==<term>,
#
# 92 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<<term>,
#
# 93 	 <var-call> -> id=<expr>;.,
#
# 94 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
#
# 95 	 <stat_list> -> <stat_list><stat>.,
#
# 96 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 97 	 <stat> -> <def-func>.,
#
# 98 	 <stat> -> <if-stat>.,
#
# 99 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <while-stat> -> while(<expr>){<stat_list>.},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
#
# 100 	 <while-stat> -> while(<expr>){<stat_list>}.,
#
# 101 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
#
# 102 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 103 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 104 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> <param>,.<param-list>,
# 	 <param> -> .id:type,
#
# 105 	 <param-list> -> <param>,<param-list>.,
#
# 106 	 <param> -> id.:type,
#
# 107 	 <param> -> id:.type,
#
# 108 	 <param> -> id:type.,
#
# 109 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<return-stat>,
#
# 110 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 111 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
#
# 112 	 <else-stat> -> else{<stat_list>}.,
#
# 113 	 <stat> -> .<else-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<while-stat>,
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
#
# 114 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 115 	 S' -> <program>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat> -> <def-entry>,
#  <stat_list> -> <stat_list> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <expr> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat> -> <def-func>,
#  <stat_list> -> <stat_list> <stat>,
#  <program> -> contract id ( <param-list> ) { <stat_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# \__ProgramNode: contract node.idx(n : int) [<stat>; ... <stat>;]
# 	\__AttrDeclarationNode: n : int
# 		\__VarDeclarationNode: let last_fib_calculated = <expr> : int
# 			\__ ConstantNumNode: 0
# 		\__EntryDeclarationNode: Entry get_fib(n : int)
# 			\__AttrDeclarationNode: n : int
# 				\__VarDeclarationNode: let result = <expr> : int
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__ VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__ VariableNode: result
# 		\__FuncDeclarationNode: def fib(n : int) : int
# 				\__IfNode: if <expr> then [<stat>; ... <stat>;]
# 					\__ LessThanEqualNode
# 						\__ VariableNode: n
# 						\__ ConstantNumNode: 1
# 					\__ReturnStatementNode: return <expr>
# 						\__ VariableNode: n
# 				\__ElseNode: else [<stat>; ... <stat>;]
# 					\__VarDeclarationNode: let a = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 1
# 					\__VarDeclarationNode: let b = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 2
# 					\__ReturnStatementNode: return <expr>
# 						\__ PlusNode
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: a
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: b
