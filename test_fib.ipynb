# %%
script = '''
contract get_fib_n(){
    let last_fib_calculated: nat ;
    entry get_fib(){
        let result: nat = fib(n);
        last_fib_calculated = result;
    }

    let result: nat ;
    func fib(n: nat) : nat{
        if (n <= 1) {
            return n;
        }
        else {
            let a: int = n - 1;
            let b: int = n - 2;
            return fib(a) + fib(b);
        }
    }
}
'''

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
# words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
# table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]
lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(script))
tokens = process_lexer_tokens(lexer_tokens)
# expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 <program> -> .contractid(<op-param-list{<stat_program_list>},
# 	 S' -> .<program>,
#
# 1 	 <program> -> contract.id(<op-param-list{<stat_program_list>},
#
# 2 	 <program> -> contractid.(<op-param-list{<stat_program_list>},
#
# 3 	 <param-list> -> .<param-list>,<param>,
# 	 <op-param-list -> .<param-list>,
# 	 <param-list> -> .<param>),
# 	 <op-param-list -> .),
# 	 <program> -> contractid(.<op-param-list{<stat_program_list>},
# 	 <param> -> .id:type,
#
# 4 	 <param> -> id.:type,
#
# 5 	 <param> -> id:.type,
#
# 6 	 <param> -> id:type.,
#
# 7 	 <param-list> -> <param>.),
#
# 8 	 <param-list> -> <param>).,
#
# 9 	 <param-list> -> <param-list>.,<param>,
# 	 <op-param-list -> <param-list>.,
#
# 10 	 <param> -> .id:type,
# 	 <param-list> -> <param-list>,.<param>,
#
# 11 	 <param-list> -> <param-list>,<param>.,
#
# 12 	 <program> -> contractid(<op-param-list.{<stat_program_list>},
#
# 13 	 <storage> -> .letid:type;,
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>},
# 	 <stat_program_list> -> .<stat_program_list><stat_program>,
# 	 <program> -> contractid(<op-param-list{.<stat_program_list>},
# 	 <stat_program_list> -> .<stat_program>,
# 	 <def-func> -> .funcid(<param-list>:type{<stat_list>},
# 	 <stat_program> -> .<storage>,
#
# 14 	 <def-entry> -> entry.id(<op-param-list{<stat_list>},
#
# 15 	 <def-entry> -> entryid.(<op-param-list{<stat_list>},
#
# 16 	 <param-list> -> .<param-list>,<param>,
# 	 <op-param-list -> .<param-list>,
# 	 <param-list> -> .<param>),
# 	 <op-param-list -> .),
# 	 <param> -> .id:type,
# 	 <def-entry> -> entryid(.<op-param-list{<stat_list>},
#
# 17 	 <def-entry> -> entryid(<op-param-list.{<stat_list>},
#
# 18 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <def-entry> -> entryid(<op-param-list{.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 19 	 <stat> -> <while-stat>.,
#
# 20 	 <while-stat> -> while.(<oper>){<stat_list>},
#
# 21 	 <atom> -> .num,
# 	 <oper> -> .<expr>><term>,
# 	 <oper> -> .<expr><<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr>==<term>,
# 	 <while-stat> -> while(.<oper>){<stat_list>},
# 	 <expr> -> .<expr>-<term>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> ."string_text",
#
# 22 	 <factor> -> <func-call>.,
#
# 23 	 <factor> -> <atom>.,
#
# 24 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 25 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 26 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 27 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 28 	 <arg-list> -> id,<arg-list>.,
#
# 29 	 <func-call> -> id(<arg-list>.),
#
# 30 	 <func-call> -> id(<arg-list>).,
#
# 31 	 <while-stat> -> while(<oper>.){<stat_list>},
#
# 32 	 <while-stat> -> while(<oper>).{<stat_list>},
#
# 33 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> while(<oper>){.<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 34 	 <stat> -> <if-stat>.,
#
# 35 	 <stat> -> <else-stat>.,
#
# 36 	 <if-stat> -> if.(<oper>){<stat_list>},
#
# 37 	 <atom> -> .num,
# 	 <oper> -> .<expr>><term>,
# 	 <oper> -> .<expr><<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr>==<term>,
# 	 <if-stat> -> if(.<oper>){<stat_list>},
# 	 <expr> -> .<expr>-<term>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> ."string_text",
#
# 38 	 <if-stat> -> if(<oper>.){<stat_list>},
#
# 39 	 <if-stat> -> if(<oper>).{<stat_list>},
#
# 40 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> if(<oper>){.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 41 	 <var-call> -> id.=<expr>;,
#
# 42 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <var-call> -> id=.<expr>;,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 43 	 <atom> -> false.,
#
# 44 	 <term> -> <factor>.,
#
# 45 	 <atom> -> num.,
#
# 46 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> (.<expr>),
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 47 	 <atom> -> ".string_text",
#
# 48 	 <atom> -> "string_text.",
#
# 49 	 <atom> -> "string_text".,
#
# 50 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <factor> -> (<expr>.),
#
# 51 	 <factor> -> (<expr>).,
#
# 52 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 53 	 <atom> -> true.,
#
# 54 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 55 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 56 	 <term> -> <term>/<factor>.,
#
# 57 	 <term> -> <term>*.<factor>,
# 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 58 	 <term> -> <term>*<factor>.,
#
# 59 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 60 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 61 	 <term> -> <term>./<factor>,
# 	 <expr> -> <term>.,
# 	 <term> -> <term>.*<factor>,
#
# 62 	 <expr> -> <expr>.-<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
#
# 63 	 <var-call> -> id=<expr>;.,
#
# 64 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <if-stat> -> if(<oper>){<stat_list>.},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 65 	 <if-stat> -> if(<oper>){<stat_list>}.,
#
# 66 	 <stat_list> -> <stat_list><stat>.,
#
# 67 	 <atom> -> .num,
# 	 <oper> -> .<expr>><term>,
# 	 <oper> -> .<expr><<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <expr> -> .<term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr>==<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <factor> -> .(<expr>),
# 	 <return-stat> -> return.<oper>;,
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> ."string_text",
#
# 68 	 <return-stat> -> return<oper>.;,
#
# 69 	 <return-stat> -> return<oper>;.,
#
# 70 	 <oper> -> <expr>.<=<term>,
# 	 <oper> -> <expr>.><term>,
# 	 <oper> -> <expr>.>=<term>,
# 	 <oper> -> <expr>.==<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <oper> -> <expr>.<<term>,
# 	 <oper> -> <expr>.,
# 	 <oper> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.-<term>,
#
# 71 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> <expr>==.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 72 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>==<term>.,
#
# 73 	 <oper> -> <expr>!=.<term>,
# 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 74 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>!=<term>.,
#
# 75 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 76 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr><<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 77 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <oper> -> <expr>>=.<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 78 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>>=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 79 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> <expr>>.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 80 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>><term>.,
#
# 81 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> <expr><=.<term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 82 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr><=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 83 	 <else-stat> -> else.{<stat_list>},
#
# 84 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 85 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <return-stat> -> .return<oper>;,
#
# 86 	 <else-stat> -> else{<stat_list>}.,
#
# 87 	 <let-var>> -> let.id:type=<expr>;,
#
# 88 	 <let-var>> -> letid.:type=<expr>;,
#
# 89 	 <let-var>> -> letid:.type=<expr>;,
#
# 90 	 <let-var>> -> letid:type.=<expr>;,
#
# 91 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
#
# 92 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 93 	 <let-var>> -> letid:type=<expr>;.,
#
# 94 	 <stat> -> <return-stat>.,
#
# 95 	 <stat> -> <let-var>>.,
#
# 96 	 <stat> -> <var-call>.,
#
# 97 	 <stat_list> -> <stat>.,
#
# 98 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <while-stat> -> while(<oper>){<stat_list>.},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 99 	 <while-stat> -> while(<oper>){<stat_list>}.,
#
# 100 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <def-entry> -> entryid(<op-param-list{<stat_list>.},
# 	 <return-stat> -> .return<oper>;,
#
# 101 	 <def-entry> -> entryid(<op-param-list{<stat_list>}.,
#
# 102 	 <op-param-list -> ).,
#
# 103 	 <def-func> -> func.id(<param-list>:type{<stat_list>},
#
# 104 	 <def-func> -> funcid.(<param-list>:type{<stat_list>},
#
# 105 	 <param> -> .id:type,
# 	 <param-list> -> .<param>),
# 	 <def-func> -> funcid(.<param-list>:type{<stat_list>},
# 	 <param-list> -> .<param-list>,<param>,
#
# 106 	 <param-list> -> <param-list>.,<param>,
# 	 <def-func> -> funcid(<param-list>.:type{<stat_list>},
#
# 107 	 <def-func> -> funcid(<param-list>:.type{<stat_list>},
#
# 108 	 <def-func> -> funcid(<param-list>:type.{<stat_list>},
#
# 109 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> funcid(<param-list>:type{.<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<oper>;,
#
# 110 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <def-func> -> funcid(<param-list>:type{<stat_list>.},
# 	 <return-stat> -> .return<oper>;,
#
# 111 	 <def-func> -> funcid(<param-list>:type{<stat_list>}.,
#
# 112 	 <stat_program> -> <def-entry>.,
#
# 113 	 <program> -> contractid(<op-param-list{<stat_program_list>.},
# 	 <storage> -> .letid:type;,
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>,
# 	 <stat_program> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>},
# 	 <def-func> -> .funcid(<param-list>:type{<stat_list>},
# 	 <stat_program> -> .<storage>,
#
# 114 	 <program> -> contractid(<op-param-list{<stat_program_list>}.,
#
# 115 	 <stat_program> -> <storage>.,
#
# 116 	 <stat_program_list> -> <stat_program_list><stat_program>.,
#
# 117 	 <storage> -> let.id:type;,
#
# 118 	 <storage> -> letid.:type;,
#
# 119 	 <storage> -> letid:.type;,
#
# 120 	 <storage> -> letid:type.;,
#
# 121 	 <storage> -> letid:type;.,
#
# 122 	 <stat_program> -> <def-func>.,
#
# 123 	 <stat_program_list> -> <stat_program>.,
#
# 124 	 S' -> <program>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<op-param-list -> ),
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program>,
#  <op-param-list -> ),
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <op-param-list { <stat_list> },
#  <stat_program> -> <def-entry>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param> ),
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <oper> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <oper> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> : type { <stat_list> },
#  <stat_program> -> <def-func>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <program> -> contract id ( <op-param-list { <stat_program_list> }]

# %%
'''
<stat_list> -> <stat_list> <stat>,
 <def-func> -> func id ( <param-list> : type { <stat_list> },
 <stat_program> -> <def-func>,
 <stat_program_list> -> <stat_program_list> <stat_program>,
 <program> -> contract id ( <op-param-list { <stat_program_list> }]
'''
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# \__ProgramNode: contract node.idx() [<stat>; ... <stat>;]
#
# 		\__DeclarationStorageNode: last_fib_calculated : nat
# 		\__EntryDeclarationNode: Entry get_fib()
#
# 				\__VarDeclarationNode: let result = <expr> : nat
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__ VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__ VariableNode: result
# 		\__DeclarationStorageNode: result : nat
# 		\__FuncDeclarationNode: def fib(n : nat) : nat
# 				\__IfNode: if <expr> then [<stat>; ... <stat>;]
# 					\__ LessThanEqualNode
# 						\__ VariableNode: n
# 						\__ ConstantNumNode: 1
# 					\__ReturnStatementNode: return <expr>
# 						\__ VariableNode: n
# 				\__ElseNode: else [<stat>; ... <stat>;]
# 					\__VarDeclarationNode: let a = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 1
# 					\__VarDeclarationNode: let b = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 2
# 					\__ReturnStatementNode: return <expr>
# 						\__ PlusNode
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: a
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: b
