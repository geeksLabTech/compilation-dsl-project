# %%
script = '''
contract get_fib_n(x:int){
    let last_fib_calculated: nat ;

    entry get_fib(n: nat){
        let result: nat = fib(n);
        last_fib_calculated = result;
    }

    func fib(n: nat) : nat{
        if (n <= 1) {
            return n;
        }
        else {
            let a: int = n - 1;
            let b: int = n - 2;
            return fib(a) + fib(b);
        }
    }
}
'''

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
# words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
# table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]
lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(script))
tokens = process_lexer_tokens(lexer_tokens)
# expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 <program> -> .contractid(<param-list>){<stat_program_list>},
# 	 S' -> .<program>,
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<param-list>){<stat_program_list>},
#
# 3 	 <program> -> contractid.(<param-list>){<stat_program_list>},
#
# 4 	 <program> -> contractid(.<param-list>){<stat_program_list>},
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
#
# 5 	 <param-list> -> <param>.,<param-list>,
# 	 <param-list> -> <param>.,
#
# 6 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,<param-list>,
#
# 7 	 <param-list> -> <param>,<param-list>.,
#
# 8 	 <param> -> id.:type,
#
# 9 	 <param> -> id:.type,
#
# 10 	 <param> -> id:type.,
#
# 11 	 <program> -> contractid(<param-list>.){<stat_program_list>},
#
# 12 	 <program> -> contractid(<param-list>).{<stat_program_list>},
#
# 13 	 <program> -> contractid(<param-list>){.<stat_program_list>},
# 	 <stat_program> -> .<storage>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program_list> -> .<stat_program>,
# 	 <storage> -> .letid:type;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_program_list> -> .<stat_program_list><stat_program>,
# 	 <stat_program> -> .<def-entry>,
#
# 14 	 <stat_program> -> <def-func>.,
#
# 15 	 <storage> -> let.id:type;,
#
# 16 	 <storage> -> letid.:type;,
#
# 17 	 <storage> -> letid:.type;,
#
# 18 	 <storage> -> letid:type.;,
#
# 19 	 <storage> -> letid:type;.,
#
# 20 	 <program> -> contractid(<param-list>){<stat_program_list>.},
# 	 <stat_program> -> .<storage>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_program> -> .<def-func>,
# 	 <storage> -> .letid:type;,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>,
# 	 <stat_program> -> .<def-entry>,
#
# 21 	 <program> -> contractid(<param-list>){<stat_program_list>}.,
#
# 22 	 <stat_program_list> -> <stat_program_list><stat_program>.,
#
# 23 	 <stat_program> -> <storage>.,
#
# 24 	 <stat_program> -> <def-entry>.,
#
# 25 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 26 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 27 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
#
# 28 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 29 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 30 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <stat_list> -> .<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
#
# 31 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <oper> -> .<expr>,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <return-stat> -> return.<oper>;,
# 	 <oper> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
#
# 32 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 33 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 34 	 <atom> -> false.,
#
# 35 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 36 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 37 	 <func-call> -> id(<arg-list>.),
#
# 38 	 <func-call> -> id(<arg-list>).,
#
# 39 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 40 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 41 	 <arg-list> -> id,<arg-list>.,
#
# 42 	 <atom> -> true.,
#
# 43 	 <factor> -> <func-call>.,
#
# 44 	 <atom> -> ".string_text",
#
# 45 	 <atom> -> "string_text.",
#
# 46 	 <atom> -> "string_text".,
#
# 47 	 <atom> -> num.,
#
# 48 	 <factor> -> (.<expr>),
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 49 	 <expr> -> <expr>.-<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.+<term>,
#
# 50 	 <expr> -> <expr>+.<term>,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 51 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 52 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> <term>*.<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 53 	 <factor> -> <atom>.,
#
# 54 	 <term> -> <term>*<factor>.,
#
# 55 	 <term> -> <factor>.,
#
# 56 	 <factor> -> (<expr>).,
#
# 57 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 58 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 59 	 <term> -> <term>/<factor>.,
#
# 60 	 <return-stat> -> return<oper>.;,
#
# 61 	 <return-stat> -> return<oper>;.,
#
# 62 	 <oper> -> <expr>.==<term>,
# 	 <oper> -> <expr>.<=<term>,
# 	 <oper> -> <expr>.<<term>,
# 	 <oper> -> <expr>.><term>,
# 	 <oper> -> <expr>.,
# 	 <expr> -> <expr>.+<term>,
# 	 <oper> -> <expr>.!=<term>,
# 	 <oper> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
#
# 63 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> <expr>!=.<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 64 	 <oper> -> <expr>!=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 65 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <oper> -> <expr>>=.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 66 	 <oper> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 67 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <oper> -> <expr>>.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 68 	 <oper> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 69 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> <expr>==.<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 70 	 <oper> -> <expr>==<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 71 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <oper> -> <expr><.<term>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 72 	 <oper> -> <expr><<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 73 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <atom> -> .false,
# 	 <oper> -> <expr><=.<term>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 74 	 <oper> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 75 	 <else-stat> -> else.{<stat_list>},
#
# 76 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <stat_list> -> .<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
#
# 77 	 <if-stat> -> if.(<oper>){<stat_list>},
#
# 78 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <oper> -> .<expr>,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <if-stat> -> if(.<oper>){<stat_list>},
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
#
# 79 	 <if-stat> -> if(<oper>.){<stat_list>},
#
# 80 	 <if-stat> -> if(<oper>).{<stat_list>},
#
# 81 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <stat_list> -> .<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <if-stat> -> if(<oper>){.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
#
# 82 	 <var-call> -> id.=<expr>;,
#
# 83 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <atom> -> .true,
# 	 <expr> -> .<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 84 	 <expr> -> <expr>.-<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
#
# 85 	 <var-call> -> id=<expr>;.,
#
# 86 	 <stat> -> <else-stat>.,
#
# 87 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> if(<oper>){<stat_list>.},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 88 	 <if-stat> -> if(<oper>){<stat_list>}.,
#
# 89 	 <let-var>> -> let.id:type=<expr>;,
#
# 90 	 <let-var>> -> letid.:type=<expr>;,
#
# 91 	 <let-var>> -> letid:.type=<expr>;,
#
# 92 	 <let-var>> -> letid:type.=<expr>;,
#
# 93 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <atom> -> .true,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
#
# 94 	 <expr> -> <expr>.-<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
#
# 95 	 <let-var>> -> letid:type=<expr>;.,
#
# 96 	 <stat> -> <if-stat>.,
#
# 97 	 <stat> -> <return-stat>.,
#
# 98 	 <stat> -> <while-stat>.,
#
# 99 	 <stat> -> <var-call>.,
#
# 100 	 <stat> -> <let-var>>.,
#
# 101 	 <stat_list> -> <stat_list><stat>.,
#
# 102 	 <while-stat> -> while.(<oper>){<stat_list>},
#
# 103 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <while-stat> -> while(.<oper>){<stat_list>},
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <oper> -> .<expr>,
# 	 <atom> -> .id,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .true,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
#
# 104 	 <while-stat> -> while(<oper>.){<stat_list>},
#
# 105 	 <while-stat> -> while(<oper>).{<stat_list>},
#
# 106 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <stat_list> -> .<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> while(<oper>){.<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
#
# 107 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> while(<oper>){<stat_list>.},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 108 	 <while-stat> -> while(<oper>){<stat_list>}.,
#
# 109 	 <stat_list> -> <stat>.,
#
# 110 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <else-stat> -> else{<stat_list>.},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 111 	 <else-stat> -> else{<stat_list>}.,
#
# 112 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 113 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 114 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 115 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 116 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
#
# 117 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 118 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 119 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 120 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 121 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <stat_list> -> .<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
#
# 122 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<return-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 123 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 124 	 <stat_program_list> -> <stat_program>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat_program> -> <def-entry>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <oper> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <oper> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat_program> -> <def-func>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <program> -> contract id ( <param-list> ) { <stat_program_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# \__ProgramNode: contract node.idx(x : int) [<stat>; ... <stat>;]
# 	\__AttrDeclarationNode: x : int
# 		\__DeclarationStorageNode: last_fib_calculated : nat
# 		\__EntryDeclarationNode: Entry get_fib(n : nat)
# 			\__AttrDeclarationNode: n : nat
# 				\__VarDeclarationNode: let result = <expr> : nat
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__ VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__ VariableNode: result
# 		\__FuncDeclarationNode: def fib(n : nat) : nat
# 				\__IfNode: if <expr> then [<stat>; ... <stat>;]
# 					\__ LessThanEqualNode
# 						\__ VariableNode: n
# 						\__ ConstantNumNode: 1
# 					\__ReturnStatementNode: return <expr>
# 						\__ VariableNode: n
# 				\__ElseNode: else [<stat>; ... <stat>;]
# 					\__VarDeclarationNode: let a = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 1
# 					\__VarDeclarationNode: let b = <expr> : int
# 						\__ MinusNode
# 							\__ VariableNode: n
# 							\__ ConstantNumNode: 2
# 					\__ReturnStatementNode: return <expr>
# 						\__ PlusNode
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: a
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__ VariableNode: b
