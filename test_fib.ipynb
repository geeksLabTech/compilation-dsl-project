# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_list>},
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 3 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 4 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 5 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 6 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> <param>,.<param-list>,
#
# 7 	 <param> -> id.:type,
#
# 8 	 <param> -> id:.type,
#
# 9 	 <param> -> id:type.,
#
# 10 	 <param-list> -> <param>,<param-list>.,
#
# 11 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 12 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 13 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 14 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 15 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 16 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
#
# 17 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 18 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 19 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 20 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 21 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 22 	 <stat_list> -> <stat>.,
#
# 23 	 <stat> -> <var-call>.,
#
# 24 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 25 	 <stat_list> -> <stat_list><stat>.,
#
# 26 	 <stat> -> <def-entry>.,
#
# 27 	 <stat> -> <def-func>.,
#
# 28 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 29 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 30 	 <atom> -> num.,
#
# 31 	 <atom> -> ".string_text",
#
# 32 	 <atom> -> "string_text.",
#
# 33 	 <atom> -> "string_text".,
#
# 34 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> (.<expr>),
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 35 	 <atom> -> true.,
#
# 36 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 37 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <expr> -> <expr>>=.<term>,
# 	 <atom> -> .false,
#
# 38 	 <factor> -> <func-call>.,
#
# 39 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 40 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .false,
#
# 41 	 <term> -> <term>/<factor>.,
#
# 42 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 43 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 44 	 <func-call> -> id(<arg-list>.),
#
# 45 	 <func-call> -> id(<arg-list>).,
#
# 46 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 47 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> id,.<arg-list>,
#
# 48 	 <arg-list> -> id,<arg-list>.,
#
# 49 	 <factor> -> <atom>.,
#
# 50 	 <atom> -> false.,
#
# 51 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <atom> -> ."string_text",
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 52 	 <term> -> <term>*<factor>.,
#
# 53 	 <term> -> <factor>.,
#
# 54 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>!=.<term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 55 	 <expr> -> <expr>!=<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 56 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <expr> -> <expr>==.<term>,
# 	 <atom> -> .false,
#
# 57 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>./<factor>,
#
# 58 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 59 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 60 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <expr> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 61 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr><<term>.,
#
# 62 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <expr> -> <expr>-.<term>,
# 	 <atom> -> .false,
#
# 63 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>-<term>.,
#
# 64 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> <expr><=.<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 65 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 66 	 <factor> -> (<expr>).,
#
# 67 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>>.<term>,
# 	 <atom> -> ."string_text",
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
#
# 68 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 69 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 70 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 71 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 72 	 <var-call> -> .id=<expr>;,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 73 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 74 	 <stat> -> <let-var>>.,
#
# 75 	 <stat> -> <else-stat>.,
#
# 76 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 77 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <return-stat> -> return<expr>.;,
#
# 78 	 <return-stat> -> return<expr>;.,
#
# 79 	 <stat> -> <while-stat>.,
#
# 80 	 <var-call> -> id.=<expr>;,
#
# 81 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 82 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 83 	 <var-call> -> id=<expr>;.,
#
# 84 	 <while-stat> -> while.(<expr>){<stat_list>},
#
# 85 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <while-stat> -> while(.<expr>){<stat_list>},
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 86 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <while-stat> -> while(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 87 	 <while-stat> -> while(<expr>).{<stat_list>},
#
# 88 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> while(<expr>){.<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 89 	 <while-stat> -> while(<expr>){<stat_list>.},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 90 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 91 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 92 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
#
# 93 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 94 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 95 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 96 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 97 	 <else-stat> -> else.{<stat_list>},
#
# 98 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 99 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 100 	 <let-var>> -> let.id:type=<expr>;,
#
# 101 	 <let-var>> -> letid.:type=<expr>;,
#
# 102 	 <let-var>> -> letid:.type=<expr>;,
#
# 103 	 <let-var>> -> letid:type.=<expr>;,
#
# 104 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <factor> -> .<atom>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
#
# 105 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 106 	 <let-var>> -> letid:type=<expr>;.,
#
# 107 	 <stat> -> <return-stat>.,
#
# 108 	 <stat> -> <if-stat>.,
#
# 109 	 <else-stat> -> else{<stat_list>}.,
#
# 110 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 111 	 <while-stat> -> while(<expr>){<stat_list>}.,
#
# 112 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 113 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 114 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 115 	 <program> -> contractid(<param-list>){<stat_list>}.,

# %%
productions, operations = derivation

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
from visitors.code_runner import CodeRunnerVisitor
runner = CodeRunnerVisitor()
runner.visit(ast)
# Out:
# declare var
# num
# Entry dec Node
# Func declaration node
# Calling get_fib
# <parser.tzscript_ast.EntryDeclarationNode object at 0x7f80714a0160>
# Attr
# <visitors.code_runner.ScopeContext object at 0x7f8070fb8850>
# args: [<parser.tzscript_ast.VariableNode object at 0x7f8070fb8250>]
# var
# {'n': {'type': 'int', 'value': None}}
# declare var
# Calling fib
# <parser.tzscript_ast.FuncDeclarationNode object at 0x7f8071498310>
# Attr
# <visitors.code_runner.ScopeContext object at 0x7f8070fbe1f0>
# args: [<parser.tzscript_ast.VariableNode object at 0x7f80714a0790>]
# var
# {'n': {'type': 'int', 'value': None}}
# if Node
# var
# {'n': None}
# num
# None op 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_23094/2003231297.py in <module>
#       4 from visitors.code_runner import CodeRunnerVisitor
#       5 runner = CodeRunnerVisitor()
# ----> 6 runner.visit(ast)
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#      35         if len(self.scopes[0].entry) == 1:
#      36             self.scopes[0].variables['n'] = {'type': 'nat', 'value': 5}
# ---> 37             self.visit(
#      38                 CallNode(list(self.scopes[0].entry.keys())[0], [VariableNode('n')]))
#      39
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#     268
#     269         for st in fun_node.body:
# --> 270             self.visit(st)
#     271
#     272         self.scopes.pop()
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#      87         print("declare var")
#      88         self.scopes[self.current_scope].variables[node.id] = {
# ---> 89             'type': node.type, 'value': self.type_cast(self.visit(node.expr), node.type)}
#      90
#      91     # TODO look for the var bottom up
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#     268
#     269         for st in fun_node.body:
# --> 270             self.visit(st)
#     271
#     272         self.scopes.pop()
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#      44         print('if Node')
#      45         self.go_else = False
# ---> 46         if self.visit(node.expr):
#      47             self.current_scope += 1
#      48             self.scopes.append(ScopeContext())
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in ff(*args, **kw)
#      20     dispatcher.add_target(param_type, fn)
#      21     def ff(*args, **kw):
# ---> 22       return dispatcher(*args, **kw)
#      23     ff.dispatcher = dispatcher
#      24     return ff
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/visitor_d.py in __call__(self, *args, **kw)
#      38     d = self.targets.get(typ)
#      39     if d is not None:
# ---> 40       return d(*args, **kw)
#      41     else:
#      42       issub = issubclass
#
# ~/DATA/Matcom/3 - Compilacion/compilation-dsl-project/visitors/code_runner.py in visit(self, node)
#     231         print(f'{l} op {r}')
#     232
# --> 233         return l <= r
#     234
#     235     @visitor.when(LessThanNode)
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'int'
