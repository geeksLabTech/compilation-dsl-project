# %%
script = '''
contract get_fib_n(x:int){
    let last_fib_calculated: nat ;

    entry get_fib(n: nat){
        let result: nat = fib(n);
        last_fib_calculated = result;
    }

    func fib(n: nat) : nat{
        if (n <= 1) {
            return n;
        }
        else {
            let a: int = n - 1;
            let b: int = n - 2;
            return fib(a) + fib(b);
        }
    }
}
'''

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
# words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
# table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]
lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(script))
tokens = process_lexer_tokens(lexer_tokens)
# expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_program_list>},
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<param-list>){<stat_program_list>},
#
# 3 	 <program> -> contractid.(<param-list>){<stat_program_list>},
#
# 4 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <program> -> contractid(.<param-list>){<stat_program_list>},
#
# 5 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 6 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
#
# 7 	 <param> -> id.:type,
#
# 8 	 <param> -> id:.type,
#
# 9 	 <param> -> id:type.,
#
# 10 	 <param-list> -> <param>,<param-list>.,
#
# 11 	 <program> -> contractid(<param-list>.){<stat_program_list>},
#
# 12 	 <program> -> contractid(<param-list>).{<stat_program_list>},
#
# 13 	 <stat_program> -> .<storage>,
# 	 <stat_program_list> -> .<stat_program_list><stat_program>,
# 	 <stat_program_list> -> .<stat_program>,
# 	 <stat_program> -> .<def-entry>,
# 	 <stat_program> -> .<def-func>,
# 	 <storage> -> .letid:type;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <program> -> contractid(<param-list>){.<stat_program_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
#
# 14 	 <stat_program> -> <def-func>.,
#
# 15 	 <stat_program_list> -> <stat_program>.,
#
# 16 	 <storage> -> let.id:type;,
#
# 17 	 <storage> -> letid.:type;,
#
# 18 	 <storage> -> letid:.type;,
#
# 19 	 <storage> -> letid:type.;,
#
# 20 	 <storage> -> letid:type;.,
#
# 21 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 22 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 23 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
#
# 24 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 25 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 26 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 27 	 <stat> -> <if-stat>.,
#
# 28 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<term>,
# 	 <return-stat> -> return.<oper>;,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>==<term>,
# 	 <atom> -> .true,
#
# 29 	 <factor> -> <atom>.,
#
# 30 	 <oper> -> <expr>.,
# 	 <oper> -> <expr>.!=<term>,
# 	 <oper> -> <expr>.<=<term>,
# 	 <oper> -> <expr>.==<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <oper> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <oper> -> <expr>.>=<term>,
# 	 <oper> -> <expr>.<<term>,
#
# 31 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> <expr>>.<term>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 32 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<term>,
# 	 <factor> -> (.<expr>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 33 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
#
# 34 	 <factor> -> (<expr>).,
#
# 35 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 36 	 <atom> -> true.,
#
# 37 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 38 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 39 	 <atom> -> false.,
#
# 40 	 <atom> -> ".string_text",
#
# 41 	 <atom> -> "string_text.",
#
# 42 	 <atom> -> "string_text".,
#
# 43 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 44 	 <arg-list> -> .id,<arg-list>,
# 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,
#
# 45 	 <func-call> -> id(<arg-list>.),
#
# 46 	 <func-call> -> id(<arg-list>).,
#
# 47 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 48 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 49 	 <arg-list> -> id,<arg-list>.,
#
# 50 	 <term> -> <term>/<factor>.,
#
# 51 	 <atom> -> num.,
#
# 52 	 <factor> -> <func-call>.,
#
# 53 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 54 	 <term> -> <term>*<factor>.,
#
# 55 	 <term> -> <factor>.,
#
# 56 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 57 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
#
# 58 	 <expr> -> <term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 59 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
#
# 60 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <oper> -> <expr>>=.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 61 	 <oper> -> <expr>>=<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 62 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <oper> -> <expr><.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 63 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr><<term>.,
# 	 <term> -> <term>./<factor>,
#
# 64 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> <expr>!=.<term>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 65 	 <oper> -> <expr>!=<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 66 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> <expr><=.<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 67 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 68 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <oper> -> <expr>==.<term>,
# 	 <factor> -> .<func-call>,
#
# 69 	 <oper> -> <expr>==<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 70 	 <return-stat> -> return<oper>.;,
#
# 71 	 <return-stat> -> return<oper>;.,
#
# 72 	 <else-stat> -> else.{<stat_list>},
#
# 73 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> else{.<stat_list>},
#
# 74 	 <stat> -> <while-stat>.,
#
# 75 	 <let-var>> -> let.id:type=<expr>;,
#
# 76 	 <let-var>> -> letid.:type=<expr>;,
#
# 77 	 <let-var>> -> letid:.type=<expr>;,
#
# 78 	 <let-var>> -> letid:type.=<expr>;,
#
# 79 	 <term> -> .<factor>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<term>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 80 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
#
# 81 	 <let-var>> -> letid:type=<expr>;.,
#
# 82 	 <stat> -> <else-stat>.,
#
# 83 	 <while-stat> -> while.(<oper>){<stat_list>},
#
# 84 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<term>,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <while-stat> -> while(.<oper>){<stat_list>},
# 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>==<term>,
# 	 <atom> -> .true,
#
# 85 	 <while-stat> -> while(<oper>.){<stat_list>},
#
# 86 	 <while-stat> -> while(<oper>).{<stat_list>},
#
# 87 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> while(<oper>){.<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 88 	 <var-call> -> id.=<expr>;,
#
# 89 	 <term> -> .<factor>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<term>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
#
# 90 	 <expr> -> <expr>.+<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.-<term>,
#
# 91 	 <var-call> -> id=<expr>;.,
#
# 92 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<while-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <while-stat> -> while(<oper>){<stat_list>.},
#
# 93 	 <stat> -> <var-call>.,
#
# 94 	 <stat> -> <return-stat>.,
#
# 95 	 <while-stat> -> while(<oper>){<stat_list>}.,
#
# 96 	 <stat> -> <let-var>>.,
#
# 97 	 <stat_list> -> <stat_list><stat>.,
#
# 98 	 <if-stat> -> if.(<oper>){<stat_list>},
#
# 99 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<term>,
# 	 <oper> -> .<expr>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <oper> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <if-stat> -> if(.<oper>){<stat_list>},
# 	 <term> -> .<factor>,
# 	 <atom> -> ."string_text",
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>==<term>,
# 	 <atom> -> .true,
#
# 100 	 <if-stat> -> if(<oper>.){<stat_list>},
#
# 101 	 <if-stat> -> if(<oper>).{<stat_list>},
#
# 102 	 <if-stat> -> if(<oper>){.<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 103 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <if-stat> -> if(<oper>){<stat_list>.},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 104 	 <if-stat> -> if(<oper>){<stat_list>}.,
#
# 105 	 <stat_list> -> <stat>.,
#
# 106 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 107 	 <else-stat> -> else{<stat_list>}.,
#
# 108 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<while-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 109 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 110 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 111 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 112 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param> -> .id:type,
#
# 113 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 114 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 115 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 116 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 117 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 118 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
# 	 <return-stat> -> .return<oper>;,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <var-call> -> .id=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<var-call>,
#
# 119 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 120 	 <stat_program> -> <def-entry>.,
#
# 121 	 <program> -> contractid(<param-list>){<stat_program_list>.},
# 	 <stat_program> -> .<storage>,
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>,
# 	 <stat_program> -> .<def-entry>,
# 	 <stat_program> -> .<def-func>,
# 	 <storage> -> .letid:type;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
#
# 122 	 <stat_program_list> -> <stat_program_list><stat_program>.,
#
# 123 	 <program> -> contractid(<param-list>){<stat_program_list>}.,
#
# 124 	 <stat_program> -> <storage>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat_program> -> <def-entry>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <oper> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <oper> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat_program> -> <def-func>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <program> -> contract id ( <param-list> ) { <stat_program_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [6], line 4
#       2 ast = build_slr_ast(productions, operations, tokens)
#       3 format = FormatVisitor()
# ----> 4 print(format.visit(ast))
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:23, in FormatVisitor.visit(self, node, tabs)
#      19 ans = '\t' * tabs + \
#      20     f'\\__ProgramNode: contract node.idx({sparams}) [<stat>; ... <stat>;]'
#      21 params = '\n'.join(self.visit(param, tabs + 1)
#      22                    for param in node.params)
# ---> 23 statements = '\n'.join(self.visit(child, tabs + 2)
#      24                        for child in node.statements)
#      25 # print("======>", ans)
#      26 return f'{ans}\n{params}\n{statements}'
#
# TypeError: sequence item 0: expected str instance, list found
