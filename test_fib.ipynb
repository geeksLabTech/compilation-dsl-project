# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# self,  <program>
# other (contract id ( <param-list> ) { <stat_list> }, <function <lambda> at 0x7ff8e62119e0>, None, None, None, None, None, None, None, None)
# self,  <stat_list>
# other (<stat> <stat_list>, <function <lambda> at 0x7ff8e6213a60>, None, None)
# self,  <stat_list>
# other ('<stat>', <function <lambda> at 0x7ff8e6213b00>, None)
# self,  <stat>
# other ('<def-func>', <function <lambda> at 0x7ff8e6213ba0>, None)
# self,  <stat>
# other ('<def-entry>', <function <lambda> at 0x7ff8e6213c40>, None)
# self,  <stat>
# other ('<if-stat>', <function <lambda> at 0x7ff8e6213ce0>, None)
# self,  <stat>
# other ('<else-stat>', <function <lambda> at 0x7ff8e6213d80>, None)
# self,  <stat>
# other ('<return-stat>', <function <lambda> at 0x7ff8e6213ec0>, None)
# self,  <stat>
# other ('<var-call>', <function <lambda> at 0x7ff8e6244040>, None)
# self,  <stat>
# other ('<let-var>>', <function <lambda> at 0x7ff8e62440e0>, None)
# self,  <if-stat>
# other (if ( <expr> ) { <stat_list> }, <function <lambda> at 0x7ff8e6244180>, None, None, None, None, None, None, None)
# self,  <else-stat>
# other (else { <stat_list> }, <function <lambda> at 0x7ff8e6244220>, None, None, None, None)
# self,  <return-stat>
# other (return <expr>, <function <lambda> at 0x7ff8e6244360>, None, None)
# self,  <def-func>
# other (func id ( <param-list> ) : type { <stat_list> }, <function <lambda> at 0x7ff8e62444a0>, None, None, None, None, None, None, None, None, None, None)
# self,  <def-entry>
# other (entry id ( <param-list> ) { <stat_list> }, <function <lambda> at 0x7ff8e62445e0>, None, None, None, None, None, None, None, None)
# self,  <param-list>
# other ('<param>', <function <lambda> at 0x7ff8e6244680>, None)
# self,  <param-list>
# other (<param> , <param-list>, <function <lambda> at 0x7ff8e6244720>, None, None, None)
# self,  <param>
# other (id : type, <function <lambda> at 0x7ff8e6244860>, None, None, None)
# self,  <expr-list>
# other ('<expr>', <function <lambda> at 0x7ff8e6244900>, None)
# self,  <expr-list>
# other (<expr> , <expr-list>, <function <lambda> at 0x7ff8e62449a0>, None, None, None)
# self,  <expr>
# other (<expr> + <term>, <function <lambda> at 0x7ff8e6244ae0>, None, None, None)
# self,  <expr>
# other (<expr> - <term>, <function <lambda> at 0x7ff8e6244b80>, None, None, None)
# self,  <expr>
# other (<expr> == <term>, <function <lambda> at 0x7ff8e6244c20>, None, None, None)
# self,  <expr>
# other (<expr> <= <term>, <function <lambda> at 0x7ff8e6244cc0>, None, None, None)
# self,  <expr>
# other (<expr> >= <term>, <function <lambda> at 0x7ff8e6244d60>, None, None, None)
# self,  <expr>
# other (<expr> != <term>, <function <lambda> at 0x7ff8e6244e00>, None, None, None)
# self,  <expr>
# other (<expr> < <term>, <function <lambda> at 0x7ff8e6244ea0>, None, None, None)
# self,  <expr>
# other (<expr> > <term>, <function <lambda> at 0x7ff8e6244f40>, None, None, None)
# self,  <expr>
# other ('<term>', <function <lambda> at 0x7ff8e6244fe0>, None)
# self,  <term>
# other (<term> * <factor>, <function <lambda> at 0x7ff8e6245080>, None, None, None)
# self,  <term>
# other (<term> / <factor>, <function <lambda> at 0x7ff8e6245120>, None, None, None)
# self,  <term>
# other ('<factor>', <function <lambda> at 0x7ff8e62451c0>, None)
# self,  <factor>
# other ('<atom>', <function <lambda> at 0x7ff8e6245260>, None)
# self,  <factor>
# other ('<func-call>', <function <lambda> at 0x7ff8e6245300>, None)
# self,  <factor>
# other (( <expr> ), <function <lambda> at 0x7ff8e62453a0>, None, None, None)
# self,  <atom>
# other ('num', <function <lambda> at 0x7ff8e6245440>, None)
# self,  <atom>
# other ('id', <function <lambda> at 0x7ff8e62454e0>, None)
# self,  <atom>
# other ('true', <function <lambda> at 0x7ff8e6245580>, None)
# self,  <atom>
# other ('false', <function <lambda> at 0x7ff8e6245620>, None)
# self,  <func-call>
# other (id ( <arg-list> ), <function <lambda> at 0x7ff8e62456c0>, None, None, None, None)
# self,  <var-call>
# other (id = <expr> ;, <function <lambda> at 0x7ff8e6245760>, None, None, None, None)
# self,  <let-var>>
# other (let id : type = <expr> ;, <function <lambda> at 0x7ff8e6245800>, None, None, None, None, None, None, None)
# self,  <arg-list>
# other ('id', <function <lambda> at 0x7ff8e62458a0>, None)
# self,  <arg-list>
# other (id , <arg-list>, <function <lambda> at 0x7ff8e6245940>, None, None, None)
# self,  Exp
# other (Term Term_2, <function <lambda> at 0x7ff8e6634b80>, None, <function <lambda> at 0x7ff8e6687420>)
# self,  Term
# other (Factor Factor_2, <function <lambda> at 0x7ff8e66a1080>, None, <function <lambda> at 0x7ff8e66a1120>)
# self,  Term_2
# other (| Exp, <function <lambda> at 0x7ff8e66a11c0>, None, None)
# self,  Term_2
# other (epsilon, <function <lambda> at 0x7ff8e66a1260>)
# self,  Factor
# other (Atom Atom_2, <function <lambda> at 0x7ff8e66a1300>, None, <function <lambda> at 0x7ff8e66a13a0>)
# self,  Factor_2
# other ('Term', <function <lambda> at 0x7ff8e66a1440>, None)
# self,  Factor_2
# other (epsilon, <function <lambda> at 0x7ff8e66a14e0>)
# self,  Atom
# other ('Char', <function <lambda> at 0x7ff8e66a1580>, None)
# self,  Atom
# other (( Exp ), <function <lambda> at 0x7ff8e66a1620>, None, None, None)
# self,  Atom
# other ([ CharClass ], <function <lambda> at 0x7ff8e66a16c0>, None, None, None)
# self,  Atom_2
# other ('MetaChar', <function <lambda> at 0x7ff8e66a1760>, <function <lambda> at 0x7ff8e66a1800>)
# self,  Atom_2
# other (epsilon, <function <lambda> at 0x7ff8e66a1940>)
# self,  CharClass
# other (CharClassItem CharClassItem_2, <function <lambda> at 0x7ff8e66a19e0>, None, <function <lambda> at 0x7ff8e66a1a80>)
# self,  CharClassItem
# other (Char Char_2, <function <lambda> at 0x7ff8e66a1b20>, None, <function <lambda> at 0x7ff8e66a1bc0>)
# self,  CharClassItem_2
# other ('CharClass', <function <lambda> at 0x7ff8e66a1c60>, None)
# self,  CharClassItem_2
# other (epsilon, <function <lambda> at 0x7ff8e66a1d00>)
# self,  Char
# other ('AnyChar', <function <lambda> at 0x7ff8e66a1da0>, None)
# self,  Char
# other (\ AnyChar, <function <lambda> at 0x7ff8e66a1e40>, None, None)
# self,  Char_2
# other (- Char, <function <lambda> at 0x7ff8e66a1ee0>, None, None)
# self,  Char_2
# other (epsilon, <function <lambda> at 0x7ff8e66a1f80>)
# self,  CharCount
# other (Integer Integer_2, <function <lambda> at 0x7ff8e66a2020>, None, None)
# self,  Integer
# other (Digit Digit_2, <function <lambda> at 0x7ff8e66a20c0>, None, None)
# self,  Integer_2
# other (, Integer_3, <function <lambda> at 0x7ff8e66a2160>, None, None)
# self,  Integer_2
# other (epsilon, <function <lambda> at 0x7ff8e66a2200>)
# self,  Integer_3
# other ('Integer', <function <lambda> at 0x7ff8e66a22a0>, None)
# self,  Integer_3
# other (epsilon, <function <lambda> at 0x7ff8e66a2340>)
# self,  Digit
# other ('0', <function <lambda> at 0x7ff8e66a23e0>, None)
# self,  Digit
# other ('1', <function <lambda> at 0x7ff8e66a2480>, None)
# self,  Digit
# other ('2', <function <lambda> at 0x7ff8e66a2520>, None)
# self,  Digit
# other ('3', <function <lambda> at 0x7ff8e66a25c0>, None)
# self,  Digit
# other ('4', <function <lambda> at 0x7ff8e66a2660>, None)
# self,  Digit
# other ('5', <function <lambda> at 0x7ff8e66a2700>, None)
# self,  Digit
# other ('6', <function <lambda> at 0x7ff8e66a27a0>, None)
# self,  Digit
# other ('7', <function <lambda> at 0x7ff8e66a2840>, None)
# self,  Digit
# other ('8', <function <lambda> at 0x7ff8e66a28e0>, None)
# self,  Digit
# other ('9', <function <lambda> at 0x7ff8e66a2980>, None)
# self,  Digit_2
# other ('Integer', <function <lambda> at 0x7ff8e66a2a20>, None)
# self,  Digit_2
# other (epsilon, <function <lambda> at 0x7ff8e66a2ac0>)
# self,  AnyChar
# other ('Digit', <function <lambda> at 0x7ff8e66a2b60>, None)
# self,  AnyChar
# other ('any_char', <function <lambda> at 0x7ff8e66a2c00>, None)
# self,  MetaChar
# other ('?', <function <lambda> at 0x7ff8e66a2ca0>, None)
# self,  MetaChar
# other ('*', <function <lambda> at 0x7ff8e66a2d40>, None)
# self,  MetaChar
# other ('+', <function <lambda> at 0x7ff8e66a2de0>, None)
# self,  S'
# other (<program>, <function Grammar.AugmentedGrammar.<locals>.<lambda> at 0x7ff8fc39bb00>)
# 0 	 <program> -> .contractid(<param-list>){<stat_list>},
# 	 S' -> .<program>,
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
#
# 4 	 <param-list> -> <param>.,<param-list>,
# 	 <param-list> -> <param>.,
#
# 5 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,<param-list>,
#
# 6 	 <param> -> id.:type,
#
# 7 	 <param> -> id:.type,
#
# 8 	 <param> -> id:type.,
#
# 9 	 <param-list> -> <param>,<param-list>.,
#
# 10 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 11 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 12 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
#
# 13 	 <stat> -> <return-stat>.,
#
# 14 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<term>,
# 	 <return-stat> -> return.<expr>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
#
# 15 	 <atom> -> false.,
#
# 16 	 <atom> -> num.,
#
# 17 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <return-stat> -> return<expr>.,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.><term>,
#
# 18 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 19 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <factor> -> (.<expr>),
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
#
# 20 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.><term>,
#
# 21 	 <factor> -> (<expr>).,
#
# 22 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> <expr>-.<term>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 23 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 24 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
#
# 25 	 <arg-list> -> id.,
# 	 <arg-list> -> id.,<arg-list>,
#
# 26 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,
#
# 27 	 <arg-list> -> id,<arg-list>.,
#
# 28 	 <func-call> -> id(<arg-list>.),
#
# 29 	 <func-call> -> id(<arg-list>).,
#
# 30 	 <factor> -> <func-call>.,
#
# 31 	 <term> -> <factor>.,
#
# 32 	 <atom> -> true.,
#
# 33 	 <factor> -> <atom>.,
#
# 34 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
#
# 35 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .(<expr>),
#
# 36 	 <term> -> <term>*<factor>.,
#
# 37 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 38 	 <term> -> <term>/<factor>.,
#
# 39 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>!=.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 40 	 <expr> -> <expr>!=<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 41 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> <expr>>.<term>,
#
# 42 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
#
# 43 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>>=.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 44 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 45 	 <expr> -> <expr>==.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
#
# 46 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>./<factor>,
#
# 47 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> <expr>+.<term>,
#
# 48 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>./<factor>,
#
# 49 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr><.<term>,
# 	 <factor> -> .(<expr>),
#
# 50 	 <expr> -> <expr><<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 51 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 52 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 53 	 <else-stat> -> else.{<stat_list>},
#
# 54 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
#
# 55 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat_list> -> <stat>.<stat_list>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <stat_list> -> <stat>.,
#
# 56 	 <let-var>> -> let.id:type=<expr>;,
#
# 57 	 <let-var>> -> letid.:type=<expr>;,
#
# 58 	 <let-var>> -> letid:.type=<expr>;,
#
# 59 	 <let-var>> -> letid:type.=<expr>;,
#
# 60 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<term>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
#
# 61 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.><term>,
#
# 62 	 <let-var>> -> letid:type=<expr>;.,
#
# 63 	 <stat> -> <let-var>>.,
#
# 64 	 <stat> -> <else-stat>.,
#
# 65 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 66 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 67 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
#
# 68 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 69 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 70 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
#
# 71 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
#
# 72 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 73 	 <var-call> -> id.=<expr>;,
#
# 74 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <var-call> -> id=.<expr>;,
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
#
# 75 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.><term>,
#
# 76 	 <var-call> -> id=<expr>;.,
#
# 77 	 <stat> -> <def-func>.,
#
# 78 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 79 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 80 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
#
# 81 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 82 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 83 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 84 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 85 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<def-func>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
#
# 86 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
#
# 87 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 88 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 89 	 <atom> -> .id,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>><term>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>+<term>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <expr> -> .<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
#
# 90 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.><term>,
#
# 91 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 92 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat_list> -> .<stat><stat_list>,
# 	 <var-call> -> .id=<expr>;,
# 	 <return-stat> -> .return<expr>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
#
# 93 	 <if-stat> -> if(<expr>){<stat_list>.},
#
# 94 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 95 	 <stat> -> <if-stat>.,
#
# 96 	 <stat> -> <var-call>.,
#
# 97 	 <stat> -> <def-entry>.,
#
# 98 	 <stat_list> -> <stat><stat_list>.,
#
# 99 	 <else-stat> -> else{<stat_list>.},
#
# 100 	 <else-stat> -> else{<stat_list>}.,
#
# 101 	 <program> -> contractid(<param-list>){<stat_list>.},
#
# 102 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 103 	 S' -> <program>.,
#
# [0] <---||---> ['contract', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 6] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 6, ':', 7] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 6, ':', 7, 'type', 8] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param>', 4] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12] <---||---> ['let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56] <---||---> ['id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57] <---||---> [':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58] <---||---> ['type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59] <---||---> ['=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60] <---||---> ['num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, 'num', 16] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, '<atom>', 33] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, '<factor>', 31] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, '<term>', 51] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, '<expr>', 61] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, 'let', 56, 'id', 57, ':', 58, 'type', 59, '=', 60, '<expr>', 61, ';', 62] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<let-var>>', 63] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat>', 55] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat_list>', 101] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# mira donde rompe
#
# STACk:
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 10, ')', 11, '{', 12, '<stat_list>', 101]
#
# (101, 'entry')
# {(0, 'contract'): ('SHIFT', 1), (1, 'id'): ('SHIFT', 2), (2, '('): ('SHIFT', 3), (3, 'id'): ('SHIFT', 6), (4, ','): ('REDUCE', <param-list> -> <param>), (4, ')'): ('REDUCE', <param-list> -> <param>), (5, 'id'): ('SHIFT', 6), (6, ':'): ('SHIFT', 7), (7, 'type'): ('SHIFT', 8), (8, ','): ('REDUCE', <param> -> id : type), (8, ')'): ('REDUCE', <param> -> id : type), (9, ','): ('REDUCE', <param-list> -> <param> , <param-list>), (9, ')'): ('REDUCE', <param-list> -> <param> , <param-list>), (10, ')'): ('SHIFT', 11), (11, '{'): ('SHIFT', 12), (12, 'entry'): ('SHIFT', 65), (12, 'id'): ('SHIFT', 73), (12, 'return'): ('SHIFT', 14), (12, 'else'): ('SHIFT', 53), (12, 'let'): ('SHIFT', 56), (12, 'func'): ('SHIFT', 78), (12, 'if'): ('SHIFT', 88), (13, 'id'): ('REDUCE', <stat> -> <return-stat>), (13, 'let'): ('REDUCE', <stat> -> <return-stat>), (13, 'return'): ('REDUCE', <stat> -> <return-stat>), (13, 'func'): ('REDUCE', <stat> -> <return-stat>), (13, 'if'): ('REDUCE', <stat> -> <return-stat>), (13, '}'): ('REDUCE', <stat> -> <return-stat>), (13, 'else'): ('REDUCE', <stat> -> <return-stat>), (13, 'entry'): ('REDUCE', <stat> -> <return-stat>), (14, 'id'): ('SHIFT', 23), (14, 'true'): ('SHIFT', 32), (14, 'num'): ('SHIFT', 16), (14, 'false'): ('SHIFT', 15), (14, '('): ('SHIFT', 19), (15, '+'): ('REDUCE', <atom> -> false), (15, '=='): ('REDUCE', <atom> -> false), (15, '-'): ('REDUCE', <atom> -> false), (15, ','): ('REDUCE', <atom> -> false), (15, '!='): ('REDUCE', <atom> -> false), (15, '<'): ('REDUCE', <atom> -> false), (15, ';'): ('REDUCE', <atom> -> false), (15, '>'): ('REDUCE', <atom> -> false), (15, '*'): ('REDUCE', <atom> -> false), (15, ')'): ('REDUCE', <atom> -> false), (15, '/'): ('REDUCE', <atom> -> false), (15, '<='): ('REDUCE', <atom> -> false), (15, '>='): ('REDUCE', <atom> -> false), (16, '+'): ('REDUCE', <atom> -> num), (16, '=='): ('REDUCE', <atom> -> num), (16, '-'): ('REDUCE', <atom> -> num), (16, ','): ('REDUCE', <atom> -> num), (16, '!='): ('REDUCE', <atom> -> num), (16, '<'): ('REDUCE', <atom> -> num), (16, ';'): ('REDUCE', <atom> -> num), (16, '>'): ('REDUCE', <atom> -> num), (16, '*'): ('REDUCE', <atom> -> num), (16, ')'): ('REDUCE', <atom> -> num), (16, '/'): ('REDUCE', <atom> -> num), (16, '<='): ('REDUCE', <atom> -> num), (16, '>='): ('REDUCE', <atom> -> num), (17, '!='): ('SHIFT', 39), (17, '=='): ('SHIFT', 45), (17, '>='): ('SHIFT', 43), (17, '-'): ('SHIFT', 22), (17, 'id'): ('REDUCE', <return-stat> -> return <expr>), (17, 'let'): ('REDUCE', <return-stat> -> return <expr>), (17, 'return'): ('REDUCE', <return-stat> -> return <expr>), (17, 'func'): ('REDUCE', <return-stat> -> return <expr>), (17, 'if'): ('REDUCE', <return-stat> -> return <expr>), (17, '}'): ('REDUCE', <return-stat> -> return <expr>), (17, 'else'): ('REDUCE', <return-stat> -> return <expr>), (17, 'entry'): ('REDUCE', <return-stat> -> return <expr>), (17, '+'): ('SHIFT', 47), (17, '<='): ('SHIFT', 18), (17, '<'): ('SHIFT', 49), (17, '>'): ('SHIFT', 41), (18, 'id'): ('SHIFT', 23), (18, 'num'): ('SHIFT', 16), (18, 'false'): ('SHIFT', 15), (18, 'true'): ('SHIFT', 32), (18, '('): ('SHIFT', 19), (19, 'id'): ('SHIFT', 23), (19, 'true'): ('SHIFT', 32), (19, 'num'): ('SHIFT', 16), (19, 'false'): ('SHIFT', 15), (19, '('): ('SHIFT', 19), (20, '!='): ('SHIFT', 39), (20, '=='): ('SHIFT', 45), (20, '>='): ('SHIFT', 43), (20, '-'): ('SHIFT', 22), (20, '+'): ('SHIFT', 47), (20, ')'): ('SHIFT', 21), (20, '<='): ('SHIFT', 18), (20, '<'): ('SHIFT', 49), (20, '>'): ('SHIFT', 41), (21, '+'): ('REDUCE', <factor> -> ( <expr> )), (21, '=='): ('REDUCE', <factor> -> ( <expr> )), (21, '-'): ('REDUCE', <factor> -> ( <expr> )), (21, ','): ('REDUCE', <factor> -> ( <expr> )), (21, '!='): ('REDUCE', <factor> -> ( <expr> )), (21, '<'): ('REDUCE', <factor> -> ( <expr> )), (21, ';'): ('REDUCE', <factor> -> ( <expr> )), (21, '>'): ('REDUCE', <factor> -> ( <expr> )), (21, '*'): ('REDUCE', <factor> -> ( <expr> )), (21, ')'): ('REDUCE', <factor> -> ( <expr> )), (21, '/'): ('REDUCE', <factor> -> ...
# Error. Aborting...
