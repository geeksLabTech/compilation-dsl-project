# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 <program> -> .contractid(<param-list>){<stat_list>},
# 	 S' -> .<program>,
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 4 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 5 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 6 	 <stat> -> .<def-entry>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <stat> -> .<if-stat>,
#
# 7 	 <stat> -> <let-var>>.,
#
# 8 	 <var-call> -> id.=<expr>;,
#
# 9 	 <var-call> -> id=.<expr>;,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
#
# 10 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 11 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
#
# 12 	 <arg-list> -> id.,
# 	 <arg-list> -> id.,<arg-list>,
#
# 13 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
#
# 14 	 <arg-list> -> id,<arg-list>.,
#
# 15 	 <func-call> -> id(<arg-list>.),
#
# 16 	 <func-call> -> id(<arg-list>).,
#
# 17 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
#
# 18 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>!=.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 19 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <factor> -> (.<expr>),
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
#
# 20 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
#
# 21 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 22 	 <atom> -> true.,
#
# 23 	 <term> -> <factor>.,
#
# 24 	 <factor> -> <atom>.,
#
# 25 	 <atom> -> false.,
#
# 26 	 <factor> -> <func-call>.,
#
# 27 	 <atom> -> num.,
#
# 28 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 29 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <term> -> <term>/.<factor>,
#
# 30 	 <term> -> <term>/<factor>.,
#
# 31 	 <term> -> <term>*.<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 32 	 <term> -> <term>*<factor>.,
#
# 33 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 34 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 35 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>>.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 36 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>.*<factor>,
#
# 37 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 38 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 39 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>==.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 40 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 41 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> <expr>>=.<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 42 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 43 	 <atom> -> .num,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .id,
#
# 44 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr><<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 45 	 <factor> -> (<expr>).,
#
# 46 	 <term> -> <term>./<factor>,
# 	 <expr> -> <term>.,
# 	 <term> -> <term>.*<factor>,
#
# 47 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>!=<term>.,
#
# 48 	 <var-call> -> id=<expr>;.,
#
# 49 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 50 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 51 	 <param> -> .id:type,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
#
# 52 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 53 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 54 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 55 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 56 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 57 	 <stat_list> -> <stat>.,
#
# 58 	 <stat> -> <if-stat>.,
#
# 59 	 <stat> -> <else-stat>.,
#
# 60 	 <stat> -> <return-stat>.,
#
# 61 	 <else-stat> -> else.{<stat_list>},
#
# 62 	 <stat> -> .<def-entry>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 63 	 <stat> -> <var-call>.,
#
# 64 	 <stat> -> <def-entry>.,
#
# 65 	 <let-var>> -> let.id:type=<expr>;,
#
# 66 	 <let-var>> -> letid.:type=<expr>;,
#
# 67 	 <let-var>> -> letid:.type=<expr>;,
#
# 68 	 <let-var>> -> letid:type.=<expr>;,
#
# 69 	 <let-var>> -> letid:type=.<expr>;,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
#
# 70 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
#
# 71 	 <let-var>> -> letid:type=<expr>;.,
#
# 72 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
#
# 73 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
#
# 74 	 <return-stat> -> return<expr>;.,
#
# 75 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 76 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .id,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <expr> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <atom> -> .false,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>>=<term>,
# 	 <expr> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
#
# 77 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.><term>,
#
# 78 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 79 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 80 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 81 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 82 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,
#
# 83 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 84 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 85 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <stat> -> .<if-stat>,
#
# 86 	 <stat> -> <def-func>.,
#
# 87 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 88 	 <stat_list> -> <stat_list><stat>.,
#
# 89 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 90 	 <param> -> id.:type,
#
# 91 	 <param> -> id:.type,
#
# 92 	 <param> -> id:type.,
#
# 93 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 94 	 <param> -> .id:type,
# 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
#
# 95 	 <param-list> -> <param>,<param-list>.,
#
# 96 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 97 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 98 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 99 	 <else-stat> -> else{<stat_list>}.,
#
# 100 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 101 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 102 	 <stat_list> -> <stat_list>.<stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<return-stat>,
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<if-stat>,
#
# 103 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 104 	 S' -> <program>.,
#
# [0] <---||---> ['contract', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 90] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 90, ':', 91] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 90, ':', 91, 'type', 92] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param>', 93] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6] <---||---> ['let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65] <---||---> ['id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66] <---||---> [':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67] <---||---> ['type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68] <---||---> ['=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69] <---||---> ['num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'num', 27] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<atom>', 24] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<factor>', 23] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<term>', 46] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, ';', 71] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<let-var>>', 7] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat>', 57] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, 'id', 90] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, 'id', 90, ':', 91] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, 'id', 90, ':', 91, 'type', 92] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param>', 93] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85] <---||---> ['let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65] <---||---> ['id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66] <---||---> [':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67] <---||---> ['type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68] <---||---> ['=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69] <---||---> ['id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10] <---||---> ['(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10, '(', 11] <---||---> ['id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10, '(', 11, 'id', 12] <---||---> [')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10, '(', 11, '<arg-list>', 15] <---||---> [')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10, '(', 11, '<arg-list>', 15, ')', 16] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<func-call>', 26] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<factor>', 23] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<term>', 46] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, ';', 71] <---||---> ['id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'entry', 80, 'id', 81, '(', 82, '<param-list>', 83, ')', 84, '{', 85, '<let-var>>', 7] <---||---> ['id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# ...
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, 'id', 10] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<atom>', 24] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<factor>', 23] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<term>', 46] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, '-', 37] <---||---> ['num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, '-', 37, 'num', 27] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, '-', 37, '<atom>', 24] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, '-', 37, '<factor>', 23] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, '-', 37, '<term>', 38] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'let', 65, 'id', 66, ':', 67, 'type', 68, '=', 69, '<expr>', 70, ';', 71] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, '<let-var>>', 7] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, '<stat>', 88] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72] <---||---> ['id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, 'id', 10] <---||---> ['(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, 'id', 10, '(', 11] <---||---> ['id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, 'id', 10, '(', 11, 'id', 12] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, 'id', 10, '(', 11, '<arg-list>', 15] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, 'id', 10, '(', 11, '<arg-list>', 15, ')', 16] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<func-call>', 26] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<factor>', 23] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<term>', 46] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21] <---||---> ['id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, 'id', 10] <---||---> ['(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, 'id', 10, '(', 11] <---||---> ['id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, 'id', 10, '(', 11, 'id', 12] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, 'id', 10, '(', 11, '<arg-list>', 15] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, 'id', 10, '(', 11, '<arg-list>', 15, ')', 16] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, '<func-call>', 26] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, '<factor>', 23] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, '+', 21, '<term>', 28] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, 'return', 72, '<expr>', 73, ';', 74] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, '<return-stat>', 60] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, '<stat>', 88] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, 'else', 61, '{', 62, '<stat_list>', 98, '}', 99] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, '<else-stat>', 59] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, '<stat>', 88] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, 'func', 49, 'id', 50, '(', 51, '<param-list>', 52, ')', 53, ':', 54, 'type', 55, '{', 56, '<stat_list>', 100, '}', 101] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, '<def-func>', 86] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, '<stat>', 88] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 4, ')', 5, '{', 6, '<stat_list>', 102, '}', 103] <---||---> ['$']
# [0, '<program>', 104] <---||---> ['$']

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat> -> <def-entry>,
#  <stat_list> -> <stat_list> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <expr> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat> -> <def-func>,
#  <stat_list> -> <stat_list> <stat>,
#  <program> -> contract id ( <param-list> ) { <stat_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# \__ProgramNode: contract node.idx(n : int) [<stat>; ... <stat>;]
# 	\__AttrDeclarationNode: n : int
# 		\__VarDeclarationNode: let last_fib_calculated = <expr> : int
# 			\__ ConstantNumNode: 0
# 		\__EntryDeclarationNode: Entry get_fib(n : int)
# 			\__AttrDeclarationNode: n : int
# 				\__VarDeclarationNode: let result = <expr> : int
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__VariableNode: result
# 		\__FuncDeclarationNode: def fib(n : int) : :
# 			\__AttrDeclarationNode: n : int
# 				\__IfNode: if <expr> then [<stat>; ... <stat>;]
# 					\__<expr> LessThanEqualNode <expr>
# 						\__VariableNode: n
# 						\__ ConstantNumNode: 1
# 					\__ReturnStatementNode: return <expr>
# 						\__VariableNode: n
# 				\__ElseNode: else [<stat>; ... <stat>;]
# 					\__VarDeclarationNode: let a = <expr> : int
# 						\__<expr> MinusNode <expr>
# 							\__VariableNode: n
# 							\__ ConstantNumNode: 1
# 					\__VarDeclarationNode: let b = <expr> : int
# 						\__<expr> MinusNode <expr>
# 							\__VariableNode: n
# 							\__ ConstantNumNode: 2
# 					\__ReturnStatementNode: return <expr>
# 						\__<expr> PlusNode <expr>
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__VariableNode: a
# 							\__CallNode: fib(<expr>, ..., <expr>)
# 								\__VariableNode: b
