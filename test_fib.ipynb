# %%
script = '''
contract get_fib_n(){
    let last_fib_calculated: nat ;
    entry get_fib(){
        let result: nat = fib(n);
        last_fib_calculated = result;
    }

    let result: nat ;
    func fib(x: int, y :int, z: int) : nat{
        if (n <= 1) {
            then{
                return n;
            }
        
            else {
                let a: int = n - 1;
                let b: int = n - 2;
                return fib(a) + fib(b);
            }
        }
    }
}
'''

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
# words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
# table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]
lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(script))
tokens = process_lexer_tokens(lexer_tokens)
# expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 <program> -> .contractid(<op-param-list{<stat_program_list>},
# 	 S' -> .<program>,
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<op-param-list{<stat_program_list>},
#
# 3 	 <program> -> contractid.(<op-param-list{<stat_program_list>},
#
# 4 	 <param-list> -> .<param>,
# 	 <op-param-list -> .),
# 	 <program> -> contractid(.<op-param-list{<stat_program_list>},
# 	 <op-param-list -> .<param-list>),
# 	 <param-list> -> .<param-list>,<param>,
# 	 <param> -> .id:type,
#
# 5 	 <param> -> id.:type,
#
# 6 	 <param> -> id:.type,
#
# 7 	 <param> -> id:type.,
#
# 8 	 <program> -> contractid(<op-param-list.{<stat_program_list>},
#
# 9 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat_program_list> -> .<stat_program>,
# 	 <stat_program> -> .<storage>,
# 	 <program> -> contractid(<op-param-list{.<stat_program_list>},
# 	 <storage> -> .letid:type;,
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>},
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program_list> -> .<stat_program_list><stat_program>,
# 	 <stat_program> -> .<def-entry>,
#
# 10 	 <stat_program> -> <def-entry>.,
#
# 11 	 <def-entry> -> entry.id(<op-param-list{<stat_list>},
#
# 12 	 <def-entry> -> entryid.(<op-param-list{<stat_list>},
#
# 13 	 <param-list> -> .<param>,
# 	 <op-param-list -> .),
# 	 <def-entry> -> entryid(.<op-param-list{<stat_list>},
# 	 <op-param-list -> .<param-list>),
# 	 <param-list> -> .<param-list>,<param>,
# 	 <param> -> .id:type,
#
# 14 	 <def-entry> -> entryid(<op-param-list.{<stat_list>},
#
# 15 	 <return-stat> -> .return<oper>;,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <def-entry> -> entryid(<op-param-list{.<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 16 	 <while-stat> -> while.(<oper>){<stat_list>},
#
# 17 	 <oper> -> .<expr><<term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>,
# 	 <while-stat> -> while(.<oper>){<stat_list>},
# 	 <atom> -> ."string_text",
#
# 18 	 <factor> -> <atom>.,
#
# 19 	 <atom> -> num.,
#
# 20 	 <factor> -> <func-call>.,
#
# 21 	 <term> -> <factor>.,
#
# 22 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 23 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,<arg-list>,
#
# 24 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 25 	 <arg-list> -> id,.<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> .id,<arg-list>,
#
# 26 	 <arg-list> -> id,<arg-list>.,
#
# 27 	 <func-call> -> id(<arg-list>.),
#
# 28 	 <func-call> -> id(<arg-list>).,
#
# 29 	 <oper> -> <expr>.==<term>,
# 	 <oper> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <oper> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <oper> -> <expr>.<<term>,
# 	 <oper> -> <expr>.><term>,
# 	 <oper> -> <expr>.>=<term>,
# 	 <oper> -> <expr>.,
#
# 30 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> <expr>>.<term>,
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 31 	 <factor> -> .<func-call>,
# 	 <expr> -> .<term>,
# 	 <factor> -> (.<expr>),
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
#
# 32 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <factor> -> (<expr>.),
#
# 33 	 <atom> -> .id,
# 	 <expr> -> <expr>+.<term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 34 	 <atom> -> ".string_text",
#
# 35 	 <atom> -> "string_text.",
#
# 36 	 <atom> -> "string_text".,
#
# 37 	 <atom> -> true.,
#
# 38 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>+<term>.,
#
# 39 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 40 	 <term> -> <term>*<factor>.,
#
# 41 	 <atom> -> false.,
#
# 42 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 43 	 <term> -> <term>/<factor>.,
#
# 44 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> <expr>-.<term>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 45 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
#
# 46 	 <factor> -> (<expr>).,
#
# 47 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
#
# 48 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
#
# 49 	 <atom> -> .id,
# 	 <oper> -> <expr><=.<term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 50 	 <oper> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 51 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <oper> -> <expr>>=.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 52 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>>=<term>.,
#
# 53 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <oper> -> <expr>!=.<term>,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 54 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>!=<term>.,
#
# 55 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <oper> -> <expr>==.<term>,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 56 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>==<term>.,
#
# 57 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .false,
# 	 <term> -> .<factor>,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> <expr><.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <factor> -> .<func-call>,
#
# 58 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr><<term>.,
# 	 <term> -> <term>./<factor>,
#
# 59 	 <while-stat> -> while(<oper>.){<stat_list>},
#
# 60 	 <while-stat> -> while(<oper>).{<stat_list>},
#
# 61 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> while(<oper>){.<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 62 	 <stat> -> <var-call>.,
#
# 63 	 <stat_list> -> <stat>.,
#
# 64 	 <stat> -> <let-var>>.,
#
# 65 	 <stat> -> <if-stat>.,
#
# 66 	 <stat> -> <return-stat>.,
#
# 67 	 <let-var>> -> let.id:type=<expr>;,
#
# 68 	 <let-var>> -> letid.:type=<expr>;,
#
# 69 	 <let-var>> -> letid:.type=<expr>;,
#
# 70 	 <let-var>> -> letid:type.=<expr>;,
#
# 71 	 <factor> -> .<func-call>,
# 	 <expr> -> .<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <atom> -> .false,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
#
# 72 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
#
# 73 	 <let-var>> -> letid:type=<expr>;.,
#
# 74 	 <var-call> -> id.=<expr>;,
#
# 75 	 <factor> -> .<func-call>,
# 	 <expr> -> .<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .false,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <factor> -> .<atom>,
# 	 <term> -> .<factor>,
#
# 76 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <var-call> -> id=<expr>.;,
#
# 77 	 <var-call> -> id=<expr>;.,
#
# 78 	 <if-stat> -> if.(<oper>){then{<stat_list>}<op-else>,
#
# 79 	 <if-stat> -> if(.<oper>){then{<stat_list>}<op-else>,
# 	 <oper> -> .<expr><<term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>,
# 	 <atom> -> ."string_text",
#
# 80 	 <if-stat> -> if(<oper>.){then{<stat_list>}<op-else>,
#
# 81 	 <if-stat> -> if(<oper>).{then{<stat_list>}<op-else>,
#
# 82 	 <if-stat> -> if(<oper>){.then{<stat_list>}<op-else>,
#
# 83 	 <if-stat> -> if(<oper>){then.{<stat_list>}<op-else>,
#
# 84 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <if-stat> -> if(<oper>){then{.<stat_list>}<op-else>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 85 	 <stat> -> <while-stat>.,
#
# 86 	 <return-stat> -> return.<oper>;,
# 	 <oper> -> .<expr><<term>,
# 	 <atom> -> .false,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <oper> -> .<expr>!=<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<term>,
# 	 <oper> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <oper> -> .<expr><=<term>,
# 	 <oper> -> .<expr>,
# 	 <atom> -> ."string_text",
#
# 87 	 <return-stat> -> return<oper>.;,
#
# 88 	 <return-stat> -> return<oper>;.,
#
# 89 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> if(<oper>){then{<stat_list>.}<op-else>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 90 	 <stat_list> -> <stat_list><stat>.,
#
# 91 	 <op-else> -> .<else-stat>},
# 	 <op-else> -> .},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> if(<oper>){then{<stat_list>}.<op-else>,
#
# 92 	 <op-else> -> <else-stat>.},
#
# 93 	 <op-else> -> <else-stat>}.,
#
# 94 	 <if-stat> -> if(<oper>){then{<stat_list>}<op-else>.,
#
# 95 	 <else-stat> -> else.{<stat_list>},
#
# 96 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<while-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 97 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 98 	 <else-stat> -> else{<stat_list>}.,
#
# 99 	 <op-else> -> }.,
#
# 100 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> while(<oper>){<stat_list>.},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 101 	 <while-stat> -> while(<oper>){<stat_list>}.,
#
# 102 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-entry> -> entryid(<op-param-list{<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 103 	 <def-entry> -> entryid(<op-param-list{<stat_list>}.,
#
# 104 	 <op-param-list -> ).,
#
# 105 	 <op-param-list -> <param-list>.),
# 	 <param-list> -> <param-list>.,<param>,
#
# 106 	 <param-list> -> <param-list>,.<param>,
# 	 <param> -> .id:type,
#
# 107 	 <param-list> -> <param-list>,<param>.,
#
# 108 	 <op-param-list -> <param-list>).,
#
# 109 	 <param-list> -> <param>.,
#
# 110 	 <stat_program> -> <def-func>.,
#
# 111 	 <stat_program> -> <storage>.,
#
# 112 	 <storage> -> let.id:type;,
#
# 113 	 <storage> -> letid.:type;,
#
# 114 	 <storage> -> letid:.type;,
#
# 115 	 <storage> -> letid:type.;,
#
# 116 	 <storage> -> letid:type;.,
#
# 117 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <program> -> contractid(<op-param-list{<stat_program_list>.},
# 	 <stat_program> -> .<storage>,
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>,
# 	 <storage> -> .letid:type;,
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>},
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program> -> .<def-entry>,
#
# 118 	 <program> -> contractid(<op-param-list{<stat_program_list>}.,
#
# 119 	 <stat_program_list> -> <stat_program_list><stat_program>.,
#
# 120 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 121 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 122 	 <param-list> -> .<param>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param-list>,<param>,
# 	 <param> -> .id:type,
#
# 123 	 <param-list> -> <param-list>.,<param>,
# 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 124 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 125 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 126 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 127 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<var-call>,
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 128 	 <return-stat> -> .return<oper>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<oper>){then{<stat_list>}<op-else>,
# 	 <stat> -> .<while-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
#
# 129 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 130 	 <stat_program_list> -> <stat_program>.,

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<op-param-list -> ),
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program>,
#  <op-param-list -> ),
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <op-param-list { <stat_list> },
#  <stat_program> -> <def-entry>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <storage> -> let id : type ;,
#  <stat_program> -> <storage>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <param> -> id : type,
#  <param-list> -> <param-list> , <param>,
#  <param> -> id : type,
#  <param-list> -> <param-list> , <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <oper> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <oper> -> <expr>,
#  <return-stat> -> return <oper> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <op-else> -> <else-stat> },
#  <if-stat> -> if ( <oper> ) { then { <stat_list> } <op-else>,
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat_program> -> <def-func>,
#  <stat_program_list> -> <stat_program_list> <stat_program>,
#  <program> -> contract id ( <op-param-list { <stat_program_list> }]

# %%
'''
<stat_list> -> <stat_list> <stat>,
 <def-func> -> func id ( <param-list> : type { <stat_list> },
 <stat_program> -> <def-func>,
 <stat_program_list> -> <stat_program_list> <stat_program>,
 <program> -> contract id ( <op-param-list { <stat_program_list> }]
'''
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# \__ProgramNode: contract node.idx() [<stat>; ... <stat>;]
#
# 		\__DeclarationStorageNode: last_fib_calculated : nat
# 		\__EntryDeclarationNode: Entry get_fib()
#
# 				\__VarDeclarationNode: let result = <expr> : nat
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__ VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__ VariableNode: result
# 		\__DeclarationStorageNode: result : nat
# 		\__FuncDeclarationNode: func fib (param,...,param)[<stat>; ... <stat>;]
# 			\__AttrDeclarationNode: x : int
# 			\__AttrDeclarationNode: y : int
# 			\__AttrDeclarationNode: z : int
# 			\__IfNode: if <expr> then [<stat>; ... <stat>;] else [<stat>; ... <stat>;]
# 				\__ LessThanEqualNode
# 					\__ VariableNode: n
# 					\__ ConstantNumNode: 1
#  then
# 				\__ReturnStatementNode: return <expr>
# 					\__ VariableNode: n
#  else
# 				\__VarDeclarationNode: let a = <expr> : int
# 					\__ MinusNode
# 						\__ VariableNode: n
# 						\__ ConstantNumNode: 1
# 				\__VarDeclarationNode: let b = <expr> : int
# 					\__ MinusNode
# 						\__ VariableNode: n
# 						\__ ConstantNumNode: 2
# 				\__ReturnStatementNode: return <expr>
# 					\__ PlusNode
# 						\__CallNode: fib(<expr>, ..., <expr>)
# 							\__ VariableNode: a
# 						\__CallNode: fib(<expr>, ..., <expr>)
# 							\__ VariableNode: b
