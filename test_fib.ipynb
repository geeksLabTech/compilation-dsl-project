# %% [markdown]
# ```
# contract get_fib_n(n:int){
#     let last_fib_calculated: int = 0;
#
#     entry get_fib_n(n: int){
#         let result: int = fib(n);
#         last_fib_calculated = result;
#     }
#
#     func fib(n: int) : int{
#         if (n <= 1) {
#             return n;
#         }
#         else {
#             return fib(n-1) + fib(n-2);
#         }
#     }
# }
# ```

# %%
from lexer.tzscript_lexer import TzScriptLexer
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast
words_separated_by_spaces = ['contract','get_fib_n','(','n',':','int',')','{','let','last_fib_calculated','=', '0',';','entry','get_fib_n','(','n',':','nat',')','{','let','result', '=', 'fib','(','n',')',';','last_fib_calculated', '=', 'result',';','}','func', 'fib','(','n',':', 'nat',')',':', 'nat','{','if', '(','n', '<=', '1',')','{','return', 'n',';','}','else','{','return', 'fib','(','n', '-', '1',')', '+', 'fib','(','n', '-', '2',')',';','}','}','}']
table = [(TZSCRIPT_GRAMMAR[tok], tok) for tok in words_separated_by_spaces]

expected_tokens = [ Token(x[1], x[0]) for x in table]

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)
tokens = [Token('contract',contract),Token('get_fib_n',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let), Token('last_fib_calculated',idx), Token(':', colon), Token('int', typex), Token('=',equal),Token('0',num),Token(';',semi),Token('entry',entry),Token('get_fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token('{',ocur),Token('let',let),Token('result',idx), Token(':', colon), Token('int', typex),Token('=',equal),Token('fib',idx),Token('(',opar),Token('n',idx),Token(')',cpar),Token(';',semi),Token('last_fib_calculated',idx),Token('=',equal),Token('result',idx),Token(';',semi),Token('}',ccur),Token('func',func),Token('fib',idx),Token('(',opar),Token('n',idx),Token(':',colon),Token('int',typex),Token(')',cpar),Token(':',colon),Token('int',typex),Token('{',ocur),Token('if',ifx),Token('(',opar),Token('n',idx),Token('<=',lessthanequal),Token('1',num),Token(')',cpar),Token('{',ocur),Token('return',returnx),Token('n',idx),Token(';',semi),Token('}',ccur),Token('else',elsex),Token('{',ocur),Token('let', let), Token('a', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('1', num), Token(';', semi), Token('let', let), Token('b', idx), Token(':', colon), Token('int', typex), Token('=', equal), Token('n', idx), Token('-', minus), Token('2', num), Token(';', semi), Token('return',returnx),Token('fib',idx),Token('(',opar),Token('a',idx),Token(')',cpar),Token('+',plus),Token('fib',idx),Token('(',opar),Token('b',idx),Token(')',cpar),Token(';',semi),Token('}',ccur),Token('}',ccur),Token('}',ccur),Token('EOF',TZSCRIPT_GRAMMAR.EOF)]

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# 0 	 <program> -> .contractid(<param-list>){<stat_list>},
# 	 S' -> .<program>,
#
# 1 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 2 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 3 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
#
# 4 	 <param> -> id.:type,
#
# 5 	 <param> -> id:.type,
#
# 6 	 <param> -> id:type.,
#
# 7 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 8 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 9 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <stat_list> -> .<stat>,
#
# 10 	 <stat> -> <let-var>>.,
#
# 11 	 <var-call> -> id.=<expr>;,
#
# 12 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <var-call> -> id=.<expr>;,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
#
# 13 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> (.<expr>),
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
#
# 14 	 <func-call> -> id.(<arg-list>),
# 	 <atom> -> id.,
#
# 15 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
#
# 16 	 <func-call> -> id(<arg-list>.),
#
# 17 	 <func-call> -> id(<arg-list>).,
#
# 18 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 19 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> id,.<arg-list>,
#
# 20 	 <arg-list> -> id,<arg-list>.,
#
# 21 	 <term> -> <factor>.,
#
# 22 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 23 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
#
# 24 	 <term> -> <term>/<factor>.,
#
# 25 	 <factor> -> <atom>.,
#
# 26 	 <atom> -> false.,
#
# 27 	 <atom> -> true.,
#
# 28 	 <factor> -> <func-call>.,
#
# 29 	 <atom> -> num.,
#
# 30 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<func-call>,
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
#
# 31 	 <term> -> <term>*<factor>.,
#
# 32 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <factor> -> (<expr>.),
#
# 33 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> <expr>+.<term>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 34 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>+<term>.,
#
# 35 	 <atom> -> .num,
# 	 <expr> -> <expr>>=.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 36 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 37 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr>==.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 38 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 39 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 40 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 41 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr>!=.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 42 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>!=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 43 	 <factor> -> (<expr>).,
#
# 44 	 <atom> -> .num,
# 	 <expr> -> <expr>>.<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <factor> -> .(<expr>),
# 	 <atom> -> .true,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 45 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>.*<factor>,
#
# 46 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr><=.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 47 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 48 	 <atom> -> .num,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> .id,
# 	 <atom> -> .true,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr><.<term>,
# 	 <factor> -> .<atom>,
# 	 <atom> -> .false,
# 	 <term> -> .<term>/<factor>,
#
# 49 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr><<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 50 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
#
# 51 	 <var-call> -> id=<expr>;.,
#
# 52 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 53 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 54 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
#
# 55 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 56 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 57 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat>,
#
# 58 	 <stat> -> <else-stat>.,
#
# 59 	 <else-stat> -> else.{<stat_list>},
#
# 60 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat>,
#
# 61 	 <stat> -> <return-stat>.,
#
# 62 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 63 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
#
# 64 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
#
# 65 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 66 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat>,
#
# 67 	 <stat> -> <var-call>.,
#
# 68 	 <stat> -> <def-func>.,
#
# 69 	 <stat> -> <def-entry>.,
#
# 70 	 <let-var>> -> let.id:type=<expr>;,
#
# 71 	 <let-var>> -> letid.:type=<expr>;,
#
# 72 	 <let-var>> -> letid:.type=<expr>;,
#
# 73 	 <let-var>> -> letid:type.=<expr>;,
#
# 74 	 <let-var>> -> letid:type=.<expr>;,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
#
# 75 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.!=<term>,
#
# 76 	 <let-var>> -> letid:type=<expr>;.,
#
# 77 	 <stat> -> <if-stat>.,
#
# 78 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <expr> -> .<expr>+<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr><=<term>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .id,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <term> -> .<factor>,
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr>><term>,
# 	 <atom> -> .num,
# 	 <atom> -> .false,
#
# 79 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.>=<term>,
# 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.==<term>,
#
# 80 	 <return-stat> -> return<expr>;.,
#
# 81 	 <stat_list> -> <stat>.,
#
# 82 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <stat> -> .<def-entry>,
#
# 83 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 84 	 <stat_list> -> <stat_list><stat>.,
#
# 85 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 86 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 87 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
#
# 88 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 89 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 90 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 91 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 92 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat>,
#
# 93 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
#
# 94 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 95 	 <param-list> -> <param>.,<param-list>,
# 	 <param-list> -> <param>.,
#
# 96 	 <param-list> -> .<param>,<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param> -> .id:type,
# 	 <param-list> -> <param>,.<param-list>,
#
# 97 	 <param-list> -> <param>,<param-list>.,
#
# 98 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <else-stat> -> else{<stat_list>.},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
#
# 99 	 <else-stat> -> else{<stat_list>}.,
#
# 100 	 <stat> -> .<let-var>>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
#
# 101 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 102 	 <stat> -> .<let-var>>,
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<else-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-entry>,
#
# 103 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# 104 	 S' -> <program>.,
#
# [0] <---||---> ['contract', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 4] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 4, ':', 5] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, 'id', 4, ':', 5, 'type', 6] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param>', 95] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9] <---||---> ['let', 'id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70] <---||---> ['id', ':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71] <---||---> [':', 'type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72] <---||---> ['type', '=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73] <---||---> ['=', 'num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74] <---||---> ['num', ';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'num', 29] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<atom>', 25] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<factor>', 21] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<term>', 22] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75] <---||---> [';', 'entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, ';', 76] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<let-var>>', 10] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat>', 81] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102] <---||---> ['entry', 'id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53] <---||---> ['(', 'id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54] <---||---> ['id', ':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, 'id', 4] <---||---> [':', 'type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, 'id', 4, ':', 5] <---||---> ['type', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, 'id', 4, ':', 5, 'type', 6] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param>', 95] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57] <---||---> ['let', 'id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70] <---||---> ['id', ':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71] <---||---> [':', 'type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72] <---||---> ['type', '=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73] <---||---> ['=', 'id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74] <---||---> ['id', '(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14] <---||---> ['(', 'id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14, '(', 15] <---||---> ['id', ')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14, '(', 15, 'id', 18] <---||---> [')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14, '(', 15, '<arg-list>', 16] <---||---> [')', ';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14, '(', 15, '<arg-list>', 16, ')', 17] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<func-call>', 28] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<factor>', 21] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<term>', 22] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75] <---||---> [';', 'id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, ';', 76] <---||---> ['id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'entry', 52, 'id', 53, '(', 54, '<param-list>', 55, ')', 56, '{', 57, '<let-var>>', 10] <---||---> ['id', '=', 'id', ';', '}', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'if', '(', 'id', '<=', 'num', ')', '{', 'return', 'id', ';', '}', 'else', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# ...
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, 'id', 14] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<atom>', 25] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<factor>', 21] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<term>', 22] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, '-', 39] <---||---> ['num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, '-', 39, 'num', 29] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, '-', 39, '<atom>', 25] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, '-', 39, '<factor>', 21] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, '-', 39, '<term>', 40] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'let', 70, 'id', 71, ':', 72, 'type', 73, '=', 74, '<expr>', 75, ';', 76] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, '<let-var>>', 10] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, '<stat>', 84] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78] <---||---> ['id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, 'id', 14] <---||---> ['(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, 'id', 14, '(', 15] <---||---> ['id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, 'id', 14, '(', 15, 'id', 18] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, 'id', 14, '(', 15, '<arg-list>', 16] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, 'id', 14, '(', 15, '<arg-list>', 16, ')', 17] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<func-call>', 28] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<factor>', 21] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<term>', 22] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33] <---||---> ['id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, 'id', 14] <---||---> ['(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, 'id', 14, '(', 15] <---||---> ['id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, 'id', 14, '(', 15, 'id', 18] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, 'id', 14, '(', 15, '<arg-list>', 16] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, 'id', 14, '(', 15, '<arg-list>', 16, ')', 17] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, '<func-call>', 28] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, '<factor>', 21] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, '+', 33, '<term>', 34] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, 'return', 78, '<expr>', 79, ';', 80] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, '<return-stat>', 61] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, '<stat>', 84] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, 'else', 59, '{', 60, '<stat_list>', 98, '}', 99] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, '<else-stat>', 58] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, '<stat>', 84] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93] <---||---> ['}', '}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, 'func', 85, 'id', 86, '(', 87, '<param-list>', 88, ')', 89, ':', 90, 'type', 91, '{', 92, '<stat_list>', 93, '}', 94] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, '<def-func>', 68] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, '<stat>', 84] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102] <---||---> ['}', '$']
# [0, 'contract', 1, 'id', 2, '(', 3, '<param-list>', 7, ')', 8, '{', 9, '<stat_list>', 102, '}', 103] <---||---> ['$']
# [0, '<program>', 104] <---||---> ['$']

# %%
productions, operations = derivation

# %%
productions
# Out:
# [<param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <var-call> -> id = <expr> ;,
#  <stat> -> <var-call>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-entry> -> entry id ( <param-list> ) { <stat_list> },
#  <stat> -> <def-entry>,
#  <stat_list> -> <stat_list> <stat>,
#  <param> -> id : type,
#  <param-list> -> <param>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> <= <term>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat>,
#  <if-stat> -> if ( <expr> ) { <stat_list> },
#  <stat> -> <if-stat>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat>,
#  <atom> -> id,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <atom> -> num,
#  <factor> -> <atom>,
#  <term> -> <factor>,
#  <expr> -> <expr> - <term>,
#  <let-var>> -> let id : type = <expr> ;,
#  <stat> -> <let-var>>,
#  <stat_list> -> <stat_list> <stat>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <term>,
#  <arg-list> -> id,
#  <func-call> -> id ( <arg-list> ),
#  <factor> -> <func-call>,
#  <term> -> <factor>,
#  <expr> -> <expr> + <term>,
#  <return-stat> -> return <expr> ;,
#  <stat> -> <return-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <else-stat> -> else { <stat_list> },
#  <stat> -> <else-stat>,
#  <stat_list> -> <stat_list> <stat>,
#  <def-func> -> func id ( <param-list> ) : type { <stat_list> },
#  <stat> -> <def-func>,
#  <stat_list> -> <stat_list> <stat>,
#  <program> -> contract id ( <param-list> ) { <stat_list> }]

# %%
operations
# Out:
# ['SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'SHIFT',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE',
#  'REDUCE',
#  'REDUCE',
#  'SHIFT',
#  'REDUCE']

# %%
from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# <class 'parser.tzscript_ast.VariableNode'> arg
# <parser.tzscript_ast.VariableNode object at 0x1037908d0> arg
# <parser.tzscript_ast.VariableNode object at 0x103a42bd0> child
# <class 'parser.tzscript_ast.VariableNode'> type child
# <class 'parser.tzscript_ast.VariableNode'> arg
# <parser.tzscript_ast.VariableNode object at 0x1037f7c50> arg
# <class 'parser.tzscript_ast.VariableNode'> arg
# <parser.tzscript_ast.VariableNode object at 0x1037f7ad0> arg
# \__ProgramNode: contract node.idx(n : int) [<stat>; ... <stat>;]
# 	\__AttrDeclarationNode: n : int
# 		\__VarDeclarationNode: let last_fib_calculated = <expr> : int
# 			\__ ConstantNumNode: 0
# 		\__EntryDeclarationNode: Entry get_fib(n : int)
# 			\__AttrDeclarationNode: n : int
# 				\__VarDeclarationNode: let result = <expr> : int
# 					\__CallNode: fib(<expr>, ..., <expr>)
# 						\__VariableNode: n
# 				\__VarCallNode: last_fib_calculated = <expr>
# 					\__VariableNode: result
# 		\__FuncDeclarationNode: def fib(n : int) : :
# 			\__AttrDeclarationNode: n : int
# 				\__IfNode: if <expr> then [<stat>; ... <stat>;]
# 					\__<expr> LessThanEqualNode <expr>
# 						\__VariableNode: n
# 						\__ ConstantNumNode: 1
# 					\__VariableNode: n
# 				\__ElseNode: else [<stat>; ... <stat>;]
# 					\__VarDeclarationNode: let a = <expr> : int
# 						\__<expr> MinusNode <expr>
# 							\__VariableNode: n
# 							\__ ConstantNumNode: 1
# 					\__VarDeclarationNode: let b = <expr> : int
# 						\__<expr> MinusNode <expr>
# 							\__VariableNode: n
# 							\__ ConstantNumNode: 2
# 					\__<expr> PlusNode <expr>
# 						\__CallNode: fib(<expr>, ..., <expr>)
# 							\__VariableNode: a
# 						\__CallNode: fib(<expr>, ..., <expr>)
# 							\__VariableNode: b
