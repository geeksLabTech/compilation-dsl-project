# %%
test = '''
contract test(){
    let n : int;
    entry mul (n : int){
        
        result = n * 2;
    }
}
'''

# %%
from visitors.string_rep_visitor import FormatVisitor
from utils import run_tzscript_ast_building_pipeline

ast = run_tzscript_ast_building_pipeline(test)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# 0 	 <program> -> .contractid(<op-param-list{<stat_program_list>}, {'$'}
# 	 S' -> .<program>, {'$'}
#
# 1 	 <program> -> contract.id(<op-param-list{<stat_program_list>}, {'$'}
#
# 2 	 <program> -> contractid.(<op-param-list{<stat_program_list>}, {'$'}
#
# 3 	 <op-param-list -> .), {'{'}
# 	 <param-list> -> .<param-list>,<param>, {',', ')'}
# 	 <op-param-list -> .<param-list>), {'{'}
# 	 <param-list> -> .<param>, {',', ')'}
# 	 <program> -> contractid(.<op-param-list{<stat_program_list>}, {'$'}
# 	 <param> -> .id:type, {',', ')'}
#
# 4 	 <param-list> -> <param-list>.,<param>, {',', ')'}
# 	 <op-param-list -> <param-list>.), {'{'}
#
# 5 	 <param> -> .id:type, {',', ')'}
# 	 <param-list> -> <param-list>,.<param>, {',', ')'}
#
# 6 	 <param> -> id.:type, {',', ')'}
#
# 7 	 <param> -> id:.type, {',', ')'}
#
# 8 	 <param> -> id:type., {',', ')'}
#
# 9 	 <param-list> -> <param-list>,<param>., {',', ')'}
#
# 10 	 <op-param-list -> <param-list>)., {'{'}
#
# 11 	 <param-list> -> <param>., {',', ')'}
#
# 12 	 <program> -> contractid(<op-param-list.{<stat_program_list>}, {'$'}
#
# 13 	 <def-func> -> .funcid(<param-list>):type{<stat_list>}, {'entry', '}', 'func', 'let'}
# 	 <stat_program> -> .<def-func>, {'entry', '}', 'func', 'let'}
# 	 <stat_program> -> .<def-entry>, {'entry', '}', 'func', 'let'}
# 	 <program> -> contractid(<op-param-list{.<stat_program_list>}, {'$'}
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <stat_program_list> -> .<stat_program>, {'entry', '}', 'func', 'let'}
# 	 <storage> -> .letid:type;, {'entry', '}', 'let', 'func'}
# 	 <stat_program> -> .<storage>, {'entry', '}', 'func', 'let'}
# 	 <stat_program_list> -> .<stat_program_list><stat_program>, {'entry', '}', 'let', 'func'}
#
# 14 	 <def-func> -> func.id(<param-list>):type{<stat_list>}, {'entry', '}', 'let', 'func'}
#
# 15 	 <def-func> -> funcid.(<param-list>):type{<stat_list>}, {'entry', '}', 'func', 'let'}
#
# 16 	 <param-list> -> .<param>, {',', ')'}
# 	 <param-list> -> .<param-list>,<param>, {',', ')'}
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <param> -> .id:type, {',', ')'}
#
# 17 	 <param-list> -> <param-list>.,<param>, {',', ')'}
# 	 <def-func> -> funcid(<param-list>.):type{<stat_list>}, {'entry', '}', 'func', 'let'}
#
# 18 	 <def-func> -> funcid(<param-list>).:type{<stat_list>}, {'entry', '}', 'let', 'func'}
#
# 19 	 <def-func> -> funcid(<param-list>):.type{<stat_list>}, {'entry', '}', 'func', 'let'}
#
# 20 	 <def-func> -> funcid(<param-list>):type.{<stat_list>}, {'entry', '}', 'let', 'func'}
#
# 21 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>}, {'entry', '}', 'func', 'let'}
# 	 <stat_list> -> .<stat_list><stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 22 	 <stat> -> <var-call>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 23 	 <stat> -> <return-stat>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 24 	 <stat> -> <while-stat>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 25 	 <stat> -> <let-var>>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 26 	 <var-call> -> id.=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 27 	 <comparison> -> .<comparison>>=<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <var-call> -> id=.<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '<=', '==', '>=', ';', '!=', '<'}
# 	 <equality> -> .<comparison>, {'==', '!=', ';'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ';'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ';'}
# 	 <expr> -> .<equality>, {';'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 28 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <equality> -> <comparison>., {'==', '!=', ';'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.>=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
#
# 29 	 <comparison> -> <comparison>>.<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 30 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <comparison> -> <comparison>><term>., {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
#
# 31 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <term> -> <term>+.<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
#
# 32 	 <func-call> -> id.(<arg-list>), {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> id., {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 33 	 <func-call> -> id(.<arg-list>), {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <arg-list> -> .id, {')'}
# 	 <arg-list> -> .id,<arg-list>, {')'}
#
# 34 	 <func-call> -> id(<arg-list>.), {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 35 	 <func-call> -> id(<arg-list>)., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 36 	 <arg-list> -> id.,<arg-list>, {')'}
# 	 <arg-list> -> id., {')'}
#
# 37 	 <arg-list> -> id,.<arg-list>, {')'}
# 	 <arg-list> -> .id, {')'}
# 	 <arg-list> -> .id,<arg-list>, {')'}
#
# 38 	 <arg-list> -> id,<arg-list>., {')'}
#
# 39 	 <primary> -> <func-call>., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 40 	 <primary> -> true., {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 41 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> <term>+<factor>., {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 42 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> <factor>*.<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 43 	 <subfactor> -> <primary>., {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 44 	 <primary> -> string_text., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 45 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ')'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ')'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '!=', '+', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<comparison>, {'==', '!=', ')'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <expr> -> .<equality>, {')'}
# 	 <subfactor> -> (.<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
#
# 46 	 <primary> -> id., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <func-call> -> id.(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 47 	 <func-call> -> id(.<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <arg-list> -> .id, {')'}
# 	 <arg-list> -> .id,<arg-list>, {')'}
#
# 48 	 <func-call> -> id(<arg-list>.), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 49 	 <func-call> -> id(<arg-list>)., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 50 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <comparison> -> <term>., {'>', '<=', '==', '>=', '!=', ')', '<'}
#
# 51 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> <term>+.<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
#
# 52 	 <primary> -> string_text., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 53 	 <primary> -> true., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 54 	 <subfactor> -> <primary>., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 55 	 <primary> -> <func-call>., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 56 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <term> -> <term>+<factor>., {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
#
# 57 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> <factor>/.<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 58 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ')'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <subfactor> -> (.<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ')'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '!=', '+', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<comparison>, {'==', '!=', ')'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <expr> -> .<equality>, {')'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
#
# 59 	 <subfactor> -> (<expr>.), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 60 	 <subfactor> -> (<expr>)., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 61 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <term> -> <factor>., {'>', '<=', '==', '>=', '!=', '+', ')', '-', '<'}
#
# 62 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> <factor>*.<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 63 	 <primary> -> num., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 64 	 <primary> -> false., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 65 	 <factor> -> <factor>*<subfactor>., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 66 	 <comparison> -> <comparison>.>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <equality> -> <comparison>., {'!=', '==', ')'}
#
# 67 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> <comparison>>=.<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 68 	 <term> -> <term>.+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <comparison> -> <comparison>>=<term>., {'>', '<=', '==', '>=', '!=', ')', '<'}
#
# 69 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> <term>-.<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
#
# 70 	 <term> -> <term>-<factor>., {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 71 	 <factor> -> <subfactor>., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 72 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> <comparison>>.<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 73 	 <comparison> -> <comparison>><term>., {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
#
# 74 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> <comparison><.<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 75 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <comparison> -> <comparison><<term>., {'>', '==', '<=', '>=', '!=', ')', '<'}
#
# 76 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> <comparison><=.<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 77 	 <term> -> <term>.+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <comparison> -> <comparison><=<term>., {'>', '<=', '==', '>=', '!=', ')', '<'}
#
# 78 	 <expr> -> <equality>., {')'}
# 	 <equality> -> <equality>.!=<comparison>, {'!=', '==', ')'}
# 	 <equality> -> <equality>.==<comparison>, {'!=', '==', ')'}
#
# 79 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> <equality>!=.<comparison>, {'!=', '==', ')'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '!=', '+', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
#
# 80 	 <comparison> -> <comparison>.>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <equality> -> <equality>!=<comparison>., {'!=', '==', ')'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
#
# 81 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '!=', '+', ')', '-', '<'}
# 	 <equality> -> <equality>==.<comparison>, {'!=', '==', ')'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
#
# 82 	 <comparison> -> <comparison>.>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <equality> -> <equality>==<comparison>., {'!=', '==', ')'}
#
# 83 	 <factor> -> <factor>/<subfactor>., {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
#
# 84 	 <subfactor> -> (<expr>.), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 85 	 <subfactor> -> (<expr>)., {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 86 	 <primary> -> num., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 87 	 <factor> -> <factor>*<subfactor>., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 88 	 <primary> -> false., {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 89 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <factor> -> <factor>/.<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 90 	 <factor> -> <factor>/<subfactor>., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 91 	 <factor> -> <subfactor>., {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 92 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> <term>-.<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 93 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> <term>-<factor>., {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 94 	 <factor> -> <factor>.*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> <factor>., {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> <factor>./<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 95 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> <comparison><.<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 96 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <comparison> -> <comparison><<term>., {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
#
# 97 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <comparison> -> <comparison><=.<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 98 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <comparison> -> <comparison><=<term>., {'>', '==', '<=', ';', '>=', '!=', '<'}
#
# 99 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> <comparison>>=.<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
#
# 100 	 <comparison> -> <comparison>>=<term>., {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '==', '<=', '>=', ';', '!=', '+', '-', '<'}
# 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
#
# 101 	 <comparison> -> <term>., {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> <term>.+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <term> -> <term>.-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
#
# 102 	 <equality> -> <equality>.==<comparison>, {'!=', '==', ';'}
# 	 <expr> -> <equality>., {';'}
# 	 <equality> -> <equality>.!=<comparison>, {'!=', '==', ';'}
#
# 103 	 <comparison> -> .<comparison>>=<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <equality> -> <equality>==.<comparison>, {'!=', '==', ';'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 104 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.>=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <equality> -> <equality>==<comparison>., {'!=', '==', ';'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
#
# 105 	 <comparison> -> .<comparison>>=<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <equality> -> <equality>!=.<comparison>, {'!=', '==', ';'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 106 	 <comparison> -> <comparison>.><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.<<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <equality> -> <equality>!=<comparison>., {'!=', '==', ';'}
# 	 <comparison> -> <comparison>.>=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <comparison> -> <comparison>.<=<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
#
# 107 	 <var-call> -> id=<expr>.;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 108 	 <var-call> -> id=<expr>;., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 109 	 <stat> -> <if-stat>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 110 	 <let-var>> -> let.id:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 111 	 <let-var>> -> letid.:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 112 	 <let-var>> -> letid:.type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 113 	 <let-var>> -> letid:type.=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 114 	 <comparison> -> .<comparison>>=<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '<=', '==', '>=', ';', '!=', '<'}
# 	 <equality> -> .<comparison>, {'==', '!=', ';'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ';'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <let-var>> -> letid:type=.<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ';'}
# 	 <expr> -> .<equality>, {';'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# ...
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat_list><stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 124 	 <while-stat> -> while.(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 125 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ')'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ')'}
# 	 <term> -> .<factor>, {'>', '==', '<=', '>=', '!=', '+', ')', '-', '<'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <equality> -> .<comparison>, {'==', '!=', ')'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison>>=<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><<term>, {'>', '<=', '==', '>=', '!=', ')', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '==', '<=', '>=', '!=', ')', '<'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <expr> -> .<equality>, {')'}
# 	 <term> -> .<term>-<factor>, {'>', '==', '<=', '>=', '+', '!=', ')', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', '>=', '!=', '+', ')', '-', '<', '*'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', '>=', '+', '!=', ')', '-', '<', '*'}
# 	 <while-stat> -> while(.<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 126 	 <while-stat> -> while(<expr>.){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 127 	 <while-stat> -> while(<expr>).{<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 128 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> while(<expr>){.<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat_list><stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 129 	 <stat_list> -> <stat>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 130 	 <comparison> -> .<comparison>>=<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <comparison> -> .<comparison><<term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <primary> -> .<func-call>, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <subfactor> -> .<primary>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<comparison><=<term>, {'>', '<=', '==', '>=', ';', '!=', '<'}
# 	 <equality> -> .<comparison>, {'==', '!=', ';'}
# 	 <term> -> .<term>+<factor>, {'>', '==', '<=', '>=', ';', '+', '!=', '-', '<'}
# 	 <factor> -> .<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
# 	 <factor> -> .<factor>/<subfactor>, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <term> -> .<term>-<factor>, {'>', '<=', '==', '>=', ';', '+', '!=', '-', '<'}
# 	 <func-call> -> .id(<arg-list>), {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <equality> -> .<equality>==<comparison>, {'==', '!=', ';'}
# 	 <primary> -> .false, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .id, {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <equality> -> .<equality>!=<comparison>, {'!=', '==', ';'}
# 	 <return-stat> -> return.<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <expr> -> .<equality>, {';'}
# 	 <primary> -> .string_text, {'/', '>', '==', '<=', ';', '>=', '!=', '+', '-', '<', '*'}
# 	 <comparison> -> .<term>, {'>', '==', '<=', '>=', ';', '!=', '<'}
# 	 <primary> -> .true, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <comparison> -> .<comparison>><term>, {'>', '==', '<=', ';', '>=', '!=', '<'}
# 	 <subfactor> -> .(<expr>), {'/', '>', '==', '<=', '>=', ';', '+', '!=', '-', '<', '*'}
# 	 <primary> -> .num, {'/', '>', '==', '<=', ';', '>=', '+', '!=', '-', '<', '*'}
# 	 <term> -> .<factor>, {'>', '<=', '==', '>=', ';', '!=', '+', '-', '<'}
# 	 <factor> -> .<factor>*<subfactor>, {'/', '>', '==', '<=', '>=', ';', '!=', '+', '-', '<', '*'}
#
# 131 	 <return-stat> -> return<expr>.;, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 132 	 <return-stat> -> return<expr>;., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 133 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> <stat_list>.<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> while(<expr>){<stat_list>.}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 134 	 <stat_list> -> <stat_list><stat>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 135 	 <while-stat> -> while(<expr>){<stat_list>}., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 136 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> if(<expr>){then{<stat_list>.}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> <stat_list>.<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 137 	 <if-stat> -> if(<expr>){then{<stat_list>}.<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <op-else> -> .<else-stat>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <else-stat> -> .else{<stat_list>}, {'}'}
# 	 <op-else> -> .}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 138 	 <if-stat> -> if(<expr>){then{<stat_list>}<op-else>., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 139 	 <op-else> -> <else-stat>.}, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 140 	 <op-else> -> <else-stat>}., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 141 	 <else-stat> -> else.{<stat_list>}, {'}'}
#
# 142 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <else-stat> -> else{.<stat_list>}, {'}'}
# 	 <stat_list> -> .<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat_list><stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 143 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <else-stat> -> else{<stat_list>.}, {'}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> <stat_list>.<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 144 	 <else-stat> -> else{<stat_list>}., {'}'}
#
# 145 	 <op-else> -> }., {'while', 'id', 'return', 'if', 'let', '}'}
#
# 146 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.}, {'entry', '}', 'let', 'func'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> <stat_list>.<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 147 	 <def-func> -> funcid(<param-list>):type{<stat_list>}., {'entry', '}', 'func', 'let'}
#
# 148 	 <stat_program> -> <def-func>., {'entry', '}', 'let', 'func'}
#
# 149 	 <stat_program> -> <def-entry>., {'entry', '}', 'let', 'func'}
#
# 150 	 <program> -> contractid(<op-param-list{<stat_program_list>.}, {'$'}
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <stat_program> -> .<def-func>, {'entry', '}', 'let', 'func'}
# 	 <stat_program> -> .<def-entry>, {'entry', '}', 'let', 'func'}
# 	 <def-entry> -> .entryid(<op-param-list{<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>, {'entry', '}', 'let', 'func'}
# 	 <storage> -> .letid:type;, {'entry', '}', 'let', 'func'}
# 	 <stat_program> -> .<storage>, {'entry', '}', 'let', 'func'}
#
# 151 	 <program> -> contractid(<op-param-list{<stat_program_list>}., {'$'}
#
# 152 	 <def-entry> -> entry.id(<op-param-list{<stat_list>}, {'entry', '}', 'let', 'func'}
#
# 153 	 <def-entry> -> entryid.(<op-param-list{<stat_list>}, {'entry', '}', 'func', 'let'}
#
# 154 	 <op-param-list -> .), {'{'}
# 	 <param-list> -> .<param-list>,<param>, {',', ')'}
# 	 <op-param-list -> .<param-list>), {'{'}
# 	 <param-list> -> .<param>, {',', ')'}
# 	 <def-entry> -> entryid(.<op-param-list{<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <param> -> .id:type, {',', ')'}
#
# 155 	 <def-entry> -> entryid(<op-param-list.{<stat_list>}, {'entry', '}', 'func', 'let'}
#
# 156 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <def-entry> -> entryid(<op-param-list{.<stat_list>}, {'entry', '}', 'let', 'func'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> .<stat_list><stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 157 	 <stat> -> .<var-call>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<return-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<while-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <var-call> -> .id=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<let-var>>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <let-var>> -> .letid:type=<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat> -> .<if-stat>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <if-stat> -> .if(<expr>){then{<stat_list>}<op-else>, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <while-stat> -> .while(<expr>){<stat_list>}, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <def-entry> -> entryid(<op-param-list{<stat_list>.}, {'entry', '}', 'func', 'let'}
# 	 <return-stat> -> .return<expr>;, {'while', 'id', 'return', 'if', 'let', '}'}
# 	 <stat_list> -> <stat_list>.<stat>, {'while', 'id', 'return', 'if', 'let', '}'}
#
# 158 	 <def-entry> -> entryid(<op-param-list{<stat_list>}., {'entry', '}', 'let', 'func'}
#
# 159 	 <op-param-list -> )., {'{'}
#
# 160 	 <stat_program_list> -> <stat_program_list><stat_program>., {'entry', '}', 'func', 'let'}
#
# 161 	 <storage> -> let.id:type;, {'entry', '}', 'let', 'func'}
#
# 162 	 <storage> -> letid.:type;, {'entry', '}', 'func', 'let'}
#
# 163 	 <storage> -> letid:.type;, {'entry', '}', 'let', 'func'}
#
# 164 	 <storage> -> letid:type.;, {'entry', '}', 'func', 'let'}
#
# 165 	 <storage> -> letid:type;., {'entry', '}', 'let', 'func'}
#
# 166 	 <stat_program> -> <storage>., {'entry', '}', 'let', 'func'}
#
# 167 	 <stat_program_list> -> <stat_program>., {'entry', '}', 'let', 'func'}
#
# 168 	 S' -> <program>., {'$'}
#
# \__ProgramNode: contract node.idx (param,...,param) [<stat>; ... <stat>;]
#
# 		\__DeclarationStorageNode: n : int
# 		\__EntryDeclarationNode: Entry mul (param,...,param)[<stat>; ... <stat>;]
# 			\__AttrDeclarationNode: n : int
# 				\__VarCallNode: result = <expr>
# 					\__ StarNode
# 						\__VariableNode: n
# 						\__ ConstantNumNode: 2

# %%
from visitors.high_level_ir_generator_visitor import TzScriptToHighLevelIrVisitor
from visitors.hl_string_repre import HLReprVisitor

hl = TzScriptToHighLevelIrVisitor()
hl_ir = hl.visit(ast)
# Out:
# num

# %%
from visitors.high_level_ir_generator_visitor import TzScriptToHighLevelIrVisitor
high_level_ir = TzScriptToHighLevelIrVisitor()
ir = high_level_ir.visit(ast)
# Out:
# num

# %%
from visitors.hl_string_repre import HLReprVisitor
hl_repr = HLReprVisitor()
print(hl_repr.visit(ir))
# Out:
# contract { entrypoint{...} storage{...} code{...}}
# 	entrypoint  { <id,params> , <id,params> , ... , <id,params> }
# 		\__EntryPointDeclarationNode: mul (<param> ... <param>)
# 			\__AttrDeclarationNode: n : int
# 	storage { <id,type> , <id,type> , ... , <id,type> }
# 		\__StorageDeclarationNode: n : int
# 	code { <stat> , <stat> , ... , <stat> }
# 		\__IfEntryNode: if mul then
# 			\__GetToTopNode: get n
# 			\__PushValueNode: push 2 num
# 			\__ StarNode
# 			\__ReplaceVariableNode: result

# %%
from visitors.michelson_generator_visitor import MichelsonGenerator
visit_generator = MichelsonGenerator()
code = visit_generator.visit(ir)
# Out:
# final code:
# parameter <parser.tzscript_types.TzScriptInt object at 0x107b86090> %mul;
# storage <parser.tzscript_types.TzScriptInt object at 0x107b86090>;
# code {
# UNPAIR;
# DIG 1;
# PUSH nat 2;
# MUL;
# DROP;
# DIG 0;
# DROP;
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [6], line 3
#       1 from visitors.michelson_generator_visitor import MichelsonGenerator
#       2 visit_generator = MichelsonGenerator()
# ----> 3 code = visit_generator.visit(ir)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor.py:45, in when.<locals>.f.<locals>.ff(*args, **kw)
#      44 def ff(*args, **kw):
# ---> 45     return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor.py:63, in Dispatcher.__call__(self, *args, **kw)
#      61 d = self.targets.get(typ)
#      62 if d is not None:
# ---> 63     return d(*args, **kw)
#      64 else:
#      65     issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/michelson_generator_visitor.py:112, in MichelsonGenerator.visit(self, node)
#     110 print('final code: ')
#     111 print(self.code)
# --> 112 assert len(self.stack) == 1
#     114 self.code += 'NIL operation;\n'
#     115 self.code += 'PAIR;\n'
#
# AssertionError:
