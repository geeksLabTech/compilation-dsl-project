# %%
script = '''contract store_value(admin: address){

    let msg: string ;

    entry replace(new_msg: string){
        msg = new_msg;
    } 
}
'''

# %%
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR
from parser.slr_parser import SLR1Parser, build_slr_ast

lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(script))
for x in lexer_tokens:
    print(x)
print()
tokens = process_lexer_tokens(lexer_tokens)
for x in tokens:
    print(x)
parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# Token(type='CONTRACT', value='contract', lineno=1, index=0, end=8)
# Token(type='ID', value='store_value', lineno=1, index=9, end=20)
# Token(type='LPAREN', value='(', lineno=1, index=20, end=21)
# Token(type='ID', value='admin', lineno=1, index=21, end=26)
# Token(type='COLON', value=':', lineno=1, index=26, end=27)
# Token(type='TYPE', value='address', lineno=1, index=28, end=35)
# Token(type='RPAREN', value=')', lineno=1, index=35, end=36)
# Token(type='LBRACE', value='{', lineno=1, index=36, end=37)
# Token(type='LET', value='let', lineno=3, index=43, end=46)
# Token(type='ID', value='msg', lineno=3, index=47, end=50)
# Token(type='COLON', value=':', lineno=3, index=50, end=51)
# Token(type='TYPE', value='string', lineno=3, index=52, end=58)
# Token(type='SEMICOLON', value=';', lineno=3, index=59, end=60)
# Token(type='ENTRY', value='entry', lineno=5, index=66, end=71)
# Token(type='ID', value='replace', lineno=5, index=72, end=79)
# Token(type='LPAREN', value='(', lineno=5, index=79, end=80)
# Token(type='ID', value='new_msg', lineno=5, index=80, end=87)
# Token(type='COLON', value=':', lineno=5, index=87, end=88)
# Token(type='TYPE', value='string', lineno=5, index=89, end=95)
# Token(type='RPAREN', value=')', lineno=5, index=95, end=96)
# Token(type='LBRACE', value='{', lineno=5, index=96, end=97)
# Token(type='ID', value='msg', lineno=6, index=106, end=109)
# Token(type='EQUAL', value='=', lineno=6, index=110, end=111)
# Token(type='ID', value='new_msg', lineno=6, index=112, end=119)
# Token(type='SEMICOLON', value=';', lineno=6, index=119, end=120)
# Token(type='RBRACE', value='}', lineno=7, index=125, end=126)
# Token(type='RBRACE', value='}', lineno=8, index=128, end=129)
#
# contract: contract
# id: store_value
# (: (
# id: admin
# :: :
# type: address
# ): )
# {: {
# let: let
# id: msg
# :: :
# type: string
# ;: ;
# entry: entry
# id: replace
# (: (
# id: new_msg
# :: :
# type: string
# ): )
# {: {
# id: msg
# =: =
# id: new_msg
# ;: ;
# }: }
# }: }
# $: EOF
# 0 	 S' -> .<program>,
# 	 <program> -> .contractid(<param-list>){<stat_program_list>},
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<param-list>){<stat_program_list>},
#
# 3 	 <program> -> contractid.(<param-list>){<stat_program_list>},
#
# 4 	 <param-list> -> .<param>,
# 	 <program> -> contractid(.<param-list>){<stat_program_list>},
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
#
# 5 	 <program> -> contractid(<param-list>.){<stat_program_list>},
#
# 6 	 <program> -> contractid(<param-list>).{<stat_program_list>},
#
# 7 	 <program> -> contractid(<param-list>){.<stat_program_list>},
# 	 <stat_program_list> -> .<stat_program_list><stat_program>,
# 	 <stat_program> -> .<def-entry>,
# 	 <storage> -> .letid:type;,
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program> -> .<storage>,
# 	 <stat_program_list> -> .<stat_program>,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
#
# 8 	 <stat_program> -> <def-entry>.,
#
# 9 	 <program> -> contractid(<param-list>){<stat_program_list>.},
# 	 <stat_program_list> -> <stat_program_list>.<stat_program>,
# 	 <stat_program> -> .<def-entry>,
# 	 <stat_program> -> .<def-func>,
# 	 <stat_program> -> .<storage>,
# 	 <storage> -> .letid:type;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
#
# 10 	 <program> -> contractid(<param-list>){<stat_program_list>}.,
#
# 11 	 <stat_program> -> <storage>.,
#
# 12 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 13 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 14 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
#
# 15 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 16 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 17 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 18 	 <let-var>> -> let.id:type=<expr>;,
#
# 19 	 <let-var>> -> letid.:type=<expr>;,
#
# 20 	 <let-var>> -> letid:.type=<expr>;,
#
# 21 	 <let-var>> -> letid:type.=<expr>;,
#
# 22 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <let-var>> -> letid:type=.<expr>;,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 23 	 <term> -> <factor>.,
#
# 24 	 <atom> -> ".string_text",
#
# 25 	 <atom> -> "string_text.",
#
# 26 	 <atom> -> "string_text".,
#
# 27 	 <atom> -> num.,
#
# 28 	 <factor> -> <atom>.,
#
# 29 	 <term> -> <term>./<factor>,
# 	 <expr> -> <term>.,
# 	 <term> -> <term>.*<factor>,
#
# 30 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
#
# 31 	 <term> -> <term>/<factor>.,
#
# 32 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 33 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
#
# 34 	 <func-call> -> id(<arg-list>.),
#
# 35 	 <func-call> -> id(<arg-list>).,
#
# 36 	 <arg-list> -> id.,
# 	 <arg-list> -> id.,<arg-list>,
#
# 37 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> .id,
# 	 <arg-list> -> id,.<arg-list>,
#
# 38 	 <arg-list> -> id,<arg-list>.,
#
# 39 	 <atom> -> false.,
#
# 40 	 <atom> -> true.,
#
# 41 	 <expr> -> .<expr>-<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>+<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> (.<expr>),
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 42 	 <expr> -> <expr>.-<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.+<term>,
#
# 43 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr>+.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 44 	 <term> -> <term>./<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 45 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <atom> -> ."string_text",
#
# 46 	 <term> -> <term>*<factor>.,
#
# 47 	 <factor> -> <func-call>.,
#
# 48 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr>-.<term>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 49 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
#
# 50 	 <factor> -> (<expr>).,
#
# 51 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.+<term>,
#
# 52 	 <let-var>> -> letid:type=<expr>;.,
#
# 53 	 <while-stat> -> while.(<oper>){<stat_list>},
#
# 54 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <oper> -> .<expr>!=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <term> -> .<factor>,
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <while-stat> -> while(.<oper>){<stat_list>},
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <oper> -> .<expr>><term>,
#
# 55 	 <while-stat> -> while(<oper>.){<stat_list>},
#
# 56 	 <while-stat> -> while(<oper>).{<stat_list>},
#
# 57 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> while(<oper>){.<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 58 	 <stat> -> <else-stat>.,
#
# 59 	 <stat> -> <var-call>.,
#
# 60 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <oper> -> .<expr>!=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <term> -> .<factor>,
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <return-stat> -> return.<oper>;,
# 	 <oper> -> .<expr>><term>,
#
# 61 	 <return-stat> -> return<oper>.;,
#
# 62 	 <return-stat> -> return<oper>;.,
#
# 63 	 <oper> -> <expr>.<<term>,
# 	 <oper> -> <expr>.!=<term>,
# 	 <oper> -> <expr>.>=<term>,
# 	 <oper> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <oper> -> <expr>.><term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <oper> -> <expr>.==<term>,
# 	 <oper> -> <expr>.,
#
# 64 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> <expr>>.<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 65 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr>><term>.,
#
# 66 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <oper> -> <expr>!=.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 67 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>!=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 68 	 <atom> -> .true,
# 	 <oper> -> <expr>>=.<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 69 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>>=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 70 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <oper> -> <expr><=.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 71 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr><=<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 72 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <oper> -> <expr><.<term>,
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 73 	 <term> -> <term>./<factor>,
# 	 <term> -> <term>.*<factor>,
# 	 <oper> -> <expr><<term>.,
#
# 74 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <oper> -> <expr>==.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 75 	 <term> -> <term>./<factor>,
# 	 <oper> -> <expr>==<term>.,
# 	 <term> -> <term>.*<factor>,
#
# 76 	 <var-call> -> id.=<expr>;,
#
# 77 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <atom> -> .false,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<expr>+<term>,
# 	 <var-call> -> id=.<expr>;,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> ."string_text",
#
# 78 	 <expr> -> <expr>.-<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.+<term>,
#
# 79 	 <var-call> -> id=<expr>;.,
#
# 80 	 <else-stat> -> else.{<stat_list>},
#
# 81 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 82 	 <stat> -> <while-stat>.,
#
# 83 	 <stat> -> <let-var>>.,
#
# 84 	 <stat> -> .<if-stat>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 85 	 <else-stat> -> else{<stat_list>}.,
#
# 86 	 <if-stat> -> if.(<oper>){<stat_list>},
#
# 87 	 <expr> -> .<expr>-<term>,
# 	 <atom> -> .true,
# 	 <factor> -> .<func-call>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <atom> -> ."string_text",
# 	 <oper> -> .<expr>!=<term>,
# 	 <atom> -> .false,
# 	 <oper> -> .<expr>,
# 	 <term> -> .<factor>,
# 	 <oper> -> .<expr><<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <oper> -> .<expr>>=<term>,
# 	 <expr> -> .<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <atom> -> .num,
# 	 <atom> -> .id,
# 	 <if-stat> -> if(.<oper>){<stat_list>},
# 	 <term> -> .<term>*<factor>,
# 	 <oper> -> .<expr>==<term>,
# 	 <oper> -> .<expr><=<term>,
# 	 <factor> -> .(<expr>),
# 	 <factor> -> .<atom>,
# 	 <oper> -> .<expr>><term>,
#
# 88 	 <if-stat> -> if(<oper>.){<stat_list>},
#
# 89 	 <if-stat> -> if(<oper>).{<stat_list>},
#
# 90 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <if-stat> -> if(<oper>){.<stat_list>},
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 91 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <if-stat> -> if(<oper>){<stat_list>.},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 92 	 <if-stat> -> if(<oper>){<stat_list>}.,
#
# 93 	 <stat> -> <return-stat>.,
#
# 94 	 <stat_list> -> <stat_list><stat>.,
#
# 95 	 <stat> -> <if-stat>.,
#
# 96 	 <stat_list> -> <stat>.,
#
# 97 	 <stat> -> .<if-stat>,
# 	 <while-stat> -> while(<oper>){<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 98 	 <while-stat> -> while(<oper>){<stat_list>}.,
#
# 99 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 100 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 101 	 <param-list> -> <param>.,<param-list>,
# 	 <param-list> -> <param>.,
#
# 102 	 <param-list> -> <param>,.<param-list>,
# 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
#
# 103 	 <param-list> -> <param>,<param-list>.,
#
# 104 	 <param> -> id.:type,
#
# 105 	 <param> -> id:.type,
#
# 106 	 <param> -> id:type.,
#
# 107 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 108 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 109 	 <param-list> -> .<param>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
#
# 110 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 111 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 112 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 113 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 114 	 <stat> -> .<if-stat>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat_list> -> .<stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 115 	 <stat> -> .<if-stat>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <while-stat> -> .while(<oper>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <stat> -> .<let-var>>,
# 	 <var-call> -> .id=<expr>;,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <return-stat> -> .return<oper>;,
# 	 <if-stat> -> .if(<oper>){<stat_list>},
#
# 116 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 117 	 <stat_program_list> -> <stat_program_list><stat_program>.,
#
# 118 	 <stat_program> -> <def-func>.,
#
# 119 	 <storage> -> let.id:type;,
#
# 120 	 <storage> -> letid.:type;,
#
# 121 	 <storage> -> letid:.type;,
#
# 122 	 <storage> -> letid:type.;,
#
# 123 	 <storage> -> letid:type;.,
#
# 124 	 <stat_program_list> -> <stat_program>.,

# %%
productions, operations = derivation


from visitors.string_rep_visitor import FormatVisitor
ast = build_slr_ast(productions, operations, tokens)
format = FormatVisitor()
print(format.visit(ast))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [3], line 7
#       5 ast = build_slr_ast(productions, operations, tokens)
#       6 format = FormatVisitor()
# ----> 7 print(format.visit(ast))
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:22, in when.<locals>.f.<locals>.ff(*args, **kw)
#      21 def ff(*args, **kw):
# ---> 22   return dispatcher(*args, **kw)
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/visitor_d.py:40, in Dispatcher.__call__(self, *args, **kw)
#      38 d = self.targets.get(typ)
#      39 if d is not None:
# ---> 40   return d(*args, **kw)
#      41 else:
#      42   issub = issubclass
#
# File ~/Desktop/Compilacion proyect/compilation-dsl-project/visitors/string_rep_visitor.py:23, in FormatVisitor.visit(self, node, tabs)
#      19 ans = '\t' * tabs + \
#      20     f'\\__ProgramNode: contract node.idx({sparams}) [<stat>; ... <stat>;]'
#      21 params = '\n'.join(self.visit(param, tabs + 1)
#      22                    for param in node.params)
# ---> 23 statements = '\n'.join(self.visit(child, tabs + 2)
#      24                        for child in node.statements)
#      25 # print("======>", ans)
#      26 return f'{ans}\n{params}\n{statements}'
#
# TypeError: sequence item 0: expected str instance, list found
