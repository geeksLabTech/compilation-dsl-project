# %%
test = '''
contract get_fib_n(n : int){

    func fib(n: int) : int{
        while(n > 2){
            let a: int = n - 1;
            let b: int = n - 2;
            return fib(a) + fib(b);
        }
    }
}
'''

# %%
from lexer.sly_lexer import TzScriptLexer, process_lexer_tokens 
from lexer.lex_token import Token
from parser.tzscript_grammar import TZSCRIPT_GRAMMAR,idx, num, typex, contract, ifx, elsex,equal, plus, minus, star, div,semi, colon, comma, dot, opar, cpar, ocur, ccur,let, func,entry,lessthanequal,greaterthanequal, iniquelaty, lessthan,greaterthan,equalequal, returnx
from parser.slr_parser import SLR1Parser, build_slr_ast

lexer = TzScriptLexer()
lexer_tokens = list(lexer.tokenize(test))
tokens = process_lexer_tokens(lexer_tokens)

parser = SLR1Parser(TZSCRIPT_GRAMMAR, verbose=True)

terminals = [token.token_type for token in tokens]
derivation = parser(terminals, True)
# Out:
# [contract: contract, id: get_fib_n, (: (, id: n, :: :, type: int, ): ), {: {, func: func, id: fib, (: (, id: n, :: :, type: int, ): ), :: :, type: int, {: {, while: while, (: (, id: n, >: >, num: 2, ): ), {: {, let: let, id: a, :: :, type: int, =: =, id: n, -: -, num: 1, ;: ;, let: let, id: b, :: :, type: int, =: =, id: n, -: -, num: 2, ;: ;, return: return, id: fib, (: (, id: a, ): ), +: +, id: fib, (: (, id: b, ): ), ;: ;, }: }, }: }, }: }, $: EOF]
# 0 	 <program> -> .contractid(<param-list>){<stat_list>},
# 	 S' -> .<program>,
#
# 1 	 S' -> <program>.,
#
# 2 	 <program> -> contract.id(<param-list>){<stat_list>},
#
# 3 	 <program> -> contractid.(<param-list>){<stat_list>},
#
# 4 	 <param-list> -> .<param>,
# 	 <program> -> contractid(.<param-list>){<stat_list>},
# 	 <param> -> .id:type,
# 	 <param-list> -> .<param>,<param-list>,
#
# 5 	 <param-list> -> <param>.,
# 	 <param-list> -> <param>.,<param-list>,
#
# 6 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <param> -> .id:type,
# 	 <param-list> -> <param>,.<param-list>,
#
# 7 	 <param-list> -> <param>,<param-list>.,
#
# 8 	 <param> -> id.:type,
#
# 9 	 <param> -> id:.type,
#
# 10 	 <param> -> id:type.,
#
# 11 	 <program> -> contractid(<param-list>.){<stat_list>},
#
# 12 	 <program> -> contractid(<param-list>).{<stat_list>},
#
# 13 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <program> -> contractid(<param-list>){.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 14 	 <def-entry> -> entry.id(<param-list>){<stat_list>},
#
# 15 	 <def-entry> -> entryid.(<param-list>){<stat_list>},
#
# 16 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-entry> -> entryid(.<param-list>){<stat_list>},
# 	 <param> -> .id:type,
#
# 17 	 <def-entry> -> entryid(<param-list>.){<stat_list>},
#
# 18 	 <def-entry> -> entryid(<param-list>).{<stat_list>},
#
# 19 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<return-stat>,
# 	 <def-entry> -> entryid(<param-list>){.<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 20 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <def-entry> -> entryid(<param-list>){<stat_list>.},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 21 	 <def-entry> -> entryid(<param-list>){<stat_list>}.,
#
# 22 	 <else-stat> -> else.{<stat_list>},
#
# 23 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <else-stat> -> else{.<stat_list>},
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<return-stat>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 24 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<var-call>,
# 	 <else-stat> -> else{<stat_list>.},
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 25 	 <else-stat> -> else{<stat_list>}.,
#
# 26 	 <let-var>> -> let.id:type=<expr>;,
#
# 27 	 <let-var>> -> letid.:type=<expr>;,
#
# 28 	 <let-var>> -> letid:.type=<expr>;,
#
# 29 	 <let-var>> -> letid:type.=<expr>;,
#
# 30 	 <let-var>> -> letid:type=.<expr>;,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>><term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 31 	 <atom> -> true.,
#
# 32 	 <atom> -> false.,
#
# 33 	 <term> -> <factor>.,
#
# 34 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <let-var>> -> letid:type=<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
#
# 35 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <expr> -> <expr><.<term>,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 36 	 <atom> -> id.,
# 	 <func-call> -> id.(<arg-list>),
#
# 37 	 <arg-list> -> .id,
# 	 <func-call> -> id(.<arg-list>),
# 	 <arg-list> -> .id,<arg-list>,
#
# 38 	 <func-call> -> id(<arg-list>.),
#
# 39 	 <func-call> -> id(<arg-list>).,
#
# 40 	 <arg-list> -> id.,<arg-list>,
# 	 <arg-list> -> id.,
#
# 41 	 <arg-list> -> .id,
# 	 <arg-list> -> .id,<arg-list>,
# 	 <arg-list> -> id,.<arg-list>,
#
# 42 	 <arg-list> -> id,<arg-list>.,
#
# 43 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>><term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <factor> -> (.<expr>),
# 	 <expr> -> .<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 44 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <factor> -> (<expr>.),
# 	 <expr> -> <expr>.>=<term>,
#
# 45 	 <expr> -> <expr>==.<term>,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 46 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>==<term>.,
# 	 <term> -> <term>./<factor>,
#
# 47 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <term> -> <term>*.<factor>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 48 	 <term> -> <term>*<factor>.,
#
# 49 	 <factor> -> <func-call>.,
#
# 50 	 <atom> -> num.,
#
# 51 	 <factor> -> <atom>.,
#
# 52 	 <term> -> <term>/.<factor>,
# 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <func-call> -> .id(<arg-list>),
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 53 	 <term> -> <term>/<factor>.,
#
# 54 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> <expr><=.<term>,
# 	 <atom> -> .true,
#
# 55 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr><=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 56 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>>.<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 57 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>><term>.,
# 	 <term> -> <term>./<factor>,
#
# 58 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <expr> -> <expr>!=.<term>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 59 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>!=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 60 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> <expr>-.<term>,
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 61 	 <expr> -> <expr>-<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 62 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> <expr>+.<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 63 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>+<term>.,
# 	 <term> -> <term>./<factor>,
#
# 64 	 <factor> -> (<expr>).,
#
# 65 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> <expr>>=.<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <factor> -> .<atom>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<factor>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <term> -> .<term>*<factor>,
# 	 <factor> -> .<func-call>,
# 	 <atom> -> .true,
#
# 66 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <expr>>=<term>.,
# 	 <term> -> <term>./<factor>,
#
# 67 	 <term> -> <term>.*<factor>,
# 	 <expr> -> <term>.,
# 	 <term> -> <term>./<factor>,
#
# 68 	 <expr> -> <expr><<term>.,
# 	 <term> -> <term>.*<factor>,
# 	 <term> -> <term>./<factor>,
#
# 69 	 <let-var>> -> letid:type=<expr>;.,
#
# 70 	 <stat> -> <return-stat>.,
#
# 71 	 <stat> -> <if-stat>.,
#
# 72 	 <stat> -> <def-entry>.,
#
# 73 	 <stat> -> <def-func>.,
#
# 74 	 <while-stat> -> while.(<expr>){<stat_list>},
#
# 75 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>><term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <while-stat> -> while(.<expr>){<stat_list>},
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 76 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <while-stat> -> while(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
#
# 77 	 <while-stat> -> while(<expr>).{<stat_list>},
#
# 78 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
# 	 <while-stat> -> while(<expr>){.<stat_list>},
#
# 79 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <while-stat> -> while(<expr>){<stat_list>.},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 80 	 <while-stat> -> while(<expr>){<stat_list>}.,
#
# 81 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <return-stat> -> return.<expr>;,
# 	 <expr> -> .<expr>><term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 82 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <return-stat> -> return<expr>.;,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
#
# 83 	 <return-stat> -> return<expr>;.,
#
# 84 	 <stat_list> -> <stat_list><stat>.,
#
# 85 	 <var-call> -> id.=<expr>;,
#
# 86 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>><term>,
# 	 <expr> -> .<expr><=<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <var-call> -> id=.<expr>;,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 87 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <var-call> -> id=<expr>.;,
# 	 <expr> -> <expr>.>=<term>,
#
# 88 	 <var-call> -> id=<expr>;.,
#
# 89 	 <stat> -> <let-var>>.,
#
# 90 	 <stat> -> <else-stat>.,
#
# 91 	 <def-func> -> func.id(<param-list>):type{<stat_list>},
#
# 92 	 <def-func> -> funcid.(<param-list>):type{<stat_list>},
#
# 93 	 <param-list> -> .<param>,
# 	 <param-list> -> .<param>,<param-list>,
# 	 <def-func> -> funcid(.<param-list>):type{<stat_list>},
# 	 <param> -> .id:type,
#
# 94 	 <def-func> -> funcid(<param-list>.):type{<stat_list>},
#
# 95 	 <def-func> -> funcid(<param-list>).:type{<stat_list>},
#
# 96 	 <def-func> -> funcid(<param-list>):.type{<stat_list>},
#
# 97 	 <def-func> -> funcid(<param-list>):type.{<stat_list>},
#
# 98 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<return-stat>,
# 	 <def-func> -> funcid(<param-list>):type{.<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 99 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <def-func> -> funcid(<param-list>):type{<stat_list>.},
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 100 	 <def-func> -> funcid(<param-list>):type{<stat_list>}.,
#
# 101 	 <stat> -> <var-call>.,
#
# 102 	 <stat> -> <while-stat>.,
#
# 103 	 <if-stat> -> if.(<expr>){<stat_list>},
#
# 104 	 <atom> -> .false,
# 	 <atom> -> .id,
# 	 <atom> -> .num,
# 	 <expr> -> .<expr>><term>,
# 	 <if-stat> -> if(.<expr>){<stat_list>},
# 	 <expr> -> .<expr><=<term>,
# 	 <func-call> -> .id(<arg-list>),
# 	 <expr> -> .<term>,
# 	 <factor> -> .<func-call>,
# 	 <expr> -> .<expr>-<term>,
# 	 <expr> -> .<expr>>=<term>,
# 	 <term> -> .<term>/<factor>,
# 	 <expr> -> .<expr><<term>,
# 	 <term> -> .<factor>,
# 	 <atom> -> .true,
# 	 <expr> -> .<expr>==<term>,
# 	 <expr> -> .<expr>+<term>,
# 	 <factor> -> .<atom>,
# 	 <expr> -> .<expr>!=<term>,
# 	 <factor> -> .(<expr>),
# 	 <term> -> .<term>*<factor>,
#
# 105 	 <expr> -> <expr>.<=<term>,
# 	 <expr> -> <expr>.==<term>,
# 	 <if-stat> -> if(<expr>.){<stat_list>},
# 	 <expr> -> <expr>.><term>,
# 	 <expr> -> <expr>.!=<term>,
# 	 <expr> -> <expr>.+<term>,
# 	 <expr> -> <expr>.-<term>,
# 	 <expr> -> <expr>.<<term>,
# 	 <expr> -> <expr>.>=<term>,
#
# 106 	 <if-stat> -> if(<expr>).{<stat_list>},
#
# 107 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<if-stat>,
# 	 <var-call> -> .id=<expr>;,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<def-func>,
# 	 <stat> -> .<var-call>,
# 	 <return-stat> -> .return<expr>;,
# 	 <stat> -> .<let-var>>,
# 	 <stat_list> -> .<stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<return-stat>,
# 	 <if-stat> -> if(<expr>){.<stat_list>},
# 	 <stat_list> -> .<stat_list><stat>,
# 	 <stat> -> .<else-stat>,
# 	 <stat> -> .<while-stat>,
#
# 108 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <if-stat> -> if(<expr>){<stat_list>.},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 109 	 <if-stat> -> if(<expr>){<stat_list>}.,
#
# 110 	 <stat_list> -> <stat>.,
#
# 111 	 <stat> -> .<while-stat>,
# 	 <def-entry> -> .entryid(<param-list>){<stat_list>},
# 	 <var-call> -> .id=<expr>;,
# 	 <else-stat> -> .else{<stat_list>},
# 	 <let-var>> -> .letid:type=<expr>;,
# 	 <stat> -> .<return-stat>,
# 	 <stat> -> .<def-entry>,
# 	 <stat> -> .<var-call>,
# 	 <if-stat> -> .if(<expr>){<stat_list>},
# 	 <stat> -> .<else-stat>,
# 	 <return-stat> -> .return<expr>;,
# 	 <def-func> -> .funcid(<param-list>):type{<stat_list>},
# 	 <program> -> contractid(<param-list>){<stat_list>.},
# 	 <stat> -> .<let-var>>,
# 	 <stat> -> .<if-stat>,
# 	 <stat_list> -> <stat_list>.<stat>,
# 	 <stat> -> .<def-func>,
# 	 <while-stat> -> .while(<expr>){<stat_list>},
#
# 112 	 <program> -> contractid(<param-list>){<stat_list>}.,
#
# [0] <---||---> ['contract', 'id', '(', 'id', ':', 'type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2] <---||---> ['id', '(', 'id', ':', 'type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3] <---||---> ['(', 'id', ':', 'type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4] <---||---> ['id', ':', 'type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, 'id', 8] <---||---> [':', 'type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, 'id', 8, ':', 9] <---||---> ['type', ')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, 'id', 8, ':', 9, 'type', 10] <---||---> [')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param>', 5] <---||---> [')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11] <---||---> [')', '{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12] <---||---> ['{', 'func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13] <---||---> ['func', 'id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91] <---||---> ['id', '(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92] <---||---> ['(', 'id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93] <---||---> ['id', ':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, 'id', 8] <---||---> [':', 'type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, 'id', 8, ':', 9] <---||---> ['type', ')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, 'id', 8, ':', 9, 'type', 10] <---||---> [')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param>', 5] <---||---> [')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94] <---||---> [')', ':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95] <---||---> [':', 'type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96] <---||---> ['type', '{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97] <---||---> ['{', 'while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98] <---||---> ['while', '(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74] <---||---> ['(', 'id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75] <---||---> ['id', '>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, 'id', 36] <---||---> ['>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<atom>', 51] <---||---> ['>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<factor>', 33] <---||---> ['>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<term>', 67] <---||---> ['>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76] <---||---> ['>', 'num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, '>', 56] <---||---> ['num', ')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, '>', 56, 'num', 50] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, '>', 56, '<atom>', 51] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, '>', 56, '<factor>', 33] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, '>', 56, '<term>', 57] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76] <---||---> [')', '{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77] <---||---> ['{', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78] <---||---> ['let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26] <---||---> ['id', ':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27] <---||---> [':', 'type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28] <---||---> ['type', '=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29] <---||---> ['=', 'id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30] <---||---> ['id', '-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, 'id', 36] <---||---> ['-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<atom>', 51] <---||---> ['-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<factor>', 33] <---||---> ['-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<term>', 67] <---||---> ['-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34] <---||---> ['-', 'num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60] <---||---> ['num', ';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, 'num', 50] <---||---> [';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<atom>', 51] <---||---> [';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<factor>', 33] <---||---> [';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<term>', 61] <---||---> [';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34] <---||---> [';', 'let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, ';', 69] <---||---> ['let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<let-var>>', 89] <---||---> ['let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat>', 110] <---||---> ['let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79] <---||---> ['let', 'id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26] <---||---> ['id', ':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27] <---||---> [':', 'type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28] <---||---> ['type', '=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29] <---||---> ['=', 'id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30] <---||---> ['id', '-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, 'id', 36] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<atom>', 51] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<factor>', 33] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<term>', 67] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34] <---||---> ['-', 'num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60] <---||---> ['num', ';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, 'num', 50] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<atom>', 51] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<factor>', 33] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, '-', 60, '<term>', 61] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34] <---||---> [';', 'return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'let', 26, 'id', 27, ':', 28, 'type', 29, '=', 30, '<expr>', 34, ';', 69] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, '<let-var>>', 89] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, '<stat>', 84] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79] <---||---> ['return', 'id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81] <---||---> ['id', '(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, 'id', 36] <---||---> ['(', 'id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, 'id', 36, '(', 37] <---||---> ['id', ')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, 'id', 36, '(', 37, 'id', 40] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, 'id', 36, '(', 37, '<arg-list>', 38] <---||---> [')', '+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, 'id', 36, '(', 37, '<arg-list>', 38, ')', 39] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<func-call>', 49] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<factor>', 33] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<term>', 67] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82] <---||---> ['+', 'id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62] <---||---> ['id', '(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, 'id', 36] <---||---> ['(', 'id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, 'id', 36, '(', 37] <---||---> ['id', ')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, 'id', 36, '(', 37, 'id', 40] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, 'id', 36, '(', 37, '<arg-list>', 38] <---||---> [')', ';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, 'id', 36, '(', 37, '<arg-list>', 38, ')', 39] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, '<func-call>', 49] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, '<factor>', 33] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, '+', 62, '<term>', 63] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82] <---||---> [';', '}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, 'return', 81, '<expr>', 82, ';', 83] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, '<return-stat>', 70] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, '<stat>', 84] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79] <---||---> ['}', '}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, 'while', 74, '(', 75, '<expr>', 76, ')', 77, '{', 78, '<stat_list>', 79, '}', 80] <---||---> ['}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, '<while-stat>', 102] <---||---> ['}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, '<stat>', 110] <---||---> ['}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, '<stat_list>', 99] <---||---> ['}', '}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, 'func', 91, 'id', 92, '(', 93, '<param-list>', 94, ')', 95, ':', 96, 'type', 97, '{', 98, '<stat_list>', 99, '}', 100] <---||---> ['}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, '<def-func>', 73] <---||---> ['}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, '<stat>', 110] <---||---> ['}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, '<stat_list>', 111] <---||---> ['}', '$']
# [0, 'contract', 2, 'id', 3, '(', 4, '<param-list>', 11, ')', 12, '{', 13, '<stat_list>', 111, '}', 112] <---||---> ['$']
# [0, '<program>', 1] <---||---> ['$']
